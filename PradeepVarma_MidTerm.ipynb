# %% [markdown]
# ## Brute Force Approach for Transaction Analysis

# %%
import pandas as pd
import itertools
import time
from tabulate import tabulate

def load_csv_as_transactions(csv_path):
    df = pd.read_csv(csv_path, usecols=[1], skiprows=1, names=['items'])
    return df['items'].apply(lambda x: set(x.split(' , '))).tolist()

def calculate_support(itemset, transactions):
    return sum(set(itemset).issubset(t) for t in transactions)

def find_frequent_sets(transactions, min_support, max_length=3):
    all_items = {item for transaction in transactions for item in transaction}
    subsets = []
    for length in range(1, max_length + 1):
        for combo in itertools.combinations(all_items, length):
            if (support := calculate_support(combo, transactions)) >= min_support:
                subsets.append((set(combo), support))
    return subsets

def derive_rules(frequent_sets, transactions, min_confidence):
    rules = []
    for base, base_support in frequent_sets:
        for subset in map(set, itertools.chain.from_iterable(itertools.combinations(base, r) for r in range(1, len(base)))):
            consequent = base - subset
            if len(consequent) == 0:
                continue
            subset_support = calculate_support(subset, transactions)
            confidence = base_support / subset_support if subset_support else 0
            if confidence >= min_confidence:
                rules.append((subset, consequent, confidence))
    return rules

def process_and_analyze(file_path, min_support=2, min_confidence=0.5):
    transactions = load_csv_as_transactions(file_path)
    frequent_itemsets = find_frequent_sets(transactions, min_support)
    rules = derive_rules(frequent_itemsets, transactions, min_confidence)
    return frequent_itemsets, rules

def format_output(itemsets, rules):
    itemsets_table = tabulate(
        [(i + 1, ', '.join(itemset), support) for i, (itemset, support) in enumerate(itemsets)],
        headers=["No.", "Frequent Itemset", "Support"],
        tablefmt="pretty"
    )

    rules_table = tabulate(
        [(i + 1, ', '.join(subset), ', '.join(consequent), f"{confidence:.2f}") for i, (subset, consequent, confidence) in enumerate(rules)],
        headers=["No.", "Antecedent", "Consequent", "Confidence"],
        tablefmt="pretty"
    )

    return itemsets_table, rules_table

start_time = time.time()

file_paths = [
    "/Users/pradeepvarma/Downloads/dataset/walmart_data.csv",
    "/Users/pradeepvarma/Downloads/dataset/amazon_data.csv",
    "/Users/pradeepvarma/Downloads/dataset/best_buy_data.csv",
    "/Users/pradeepvarma/Downloads/dataset/costco_data.csv",
    "/Users/pradeepvarma/Downloads/dataset/walgreens_data.csv"
]

for path in file_paths:
    itemsets, association_rules = process_and_analyze(path, 0.05, 0.5)
    print(f"Results for {path}:")
    
    # Format the output
    itemsets_table, rules_table = format_output(itemsets, association_rules)
    
    print("\nFrequent Itemsets:")
    print(itemsets_table)
    print("\nAssociation Rules:")
    print(rules_table)
    print("\n")

print("Execution Time:", time.time() - start_time)
# Out:
# Results for /Users/pradeepvarma/Downloads/dataset/walmart_data.csv:
#
# Frequent Itemsets:
# +-----+-----------------------------------------------------------------+---------+
# | No. |                        Frequent Itemset                         | Support |
# +-----+-----------------------------------------------------------------+---------+
# |  1  |                        Dog Food,  Razors                        |    3    |
# |  2  |                            Dog Food                             |   106   |
# |  3  |                         Razors,  Razors                         |   46    |
# |  4  |                    Trash Bags,  Toilet Paper                    |   53    |
# |  5  |                              Milk                               |   183   |
# |  6  |                 Dog Food,  Dog Food,  Dog Food                  |    9    |
# |  7  |                 Trash Bags,  Laundry Detergent                  |    3    |
# |  8  |                        Laundry Detergent                        |   104   |
# |  9  |                       Milk,  Milk,  Milk                        |    4    |
# | 10  |                    Trash Bags,  Toilet Paper                    |    6    |
# | 11  |                         Lotion,  Lotion                         |   45    |
# | 12  |                           Trash Bags                            |   117   |
# | 13  |                        Laundry Detergent                        |   55    |
# | 14  |                    Lotion,  Lotion,  Lotion                     |    4    |
# | 15  |                             Razors                              |   56    |
# | 16  |                          Toilet Paper                           |   115   |
# | 17  |           Paper Towels,  Paper Towels,  Paper Towels            |    2    |
# | 18  |                          Milk,  Lotion                          |   44    |
# | 19  |                           Milk,  Milk                           |   55    |
# | 20  |                          Toilet Paper                           |    7    |
# | 21  |                    Razors,  Razors,  Razors                     |    4    |
# | 22  |                          Razors,  Milk                          |    4    |
# | 23  |                        Dog Food,  Razors                        |   50    |
# | 24  |                   Paper Towels,  Paper Towels                   |   60    |
# | 25  |                             Lotion                              |   51    |
# | 26  |                          Paper Towels                           |   54    |
# | 27  |                          Razors,  Milk                          |   102   |
# | 28  |                       Toilet Paper,  Milk                       |   60    |
# | 29  |                             Razors                              |    3    |
# | 30  |                       Lotion,  Trash Bags                       |    4    |
# | 31  |                        Laundry Detergent                        |   167   |
# | 32  |                              Milk                               |   57    |
# | 33  |                          Milk,  Lotion                          |    7    |
# | 34  |                  Dog Food,  Laundry Detergent                   |    2    |
# | 35  |                    Razors,  Razors,  Razors                     |    1    |
# | 36  |                       Dog Food,  Dog Food                       |   60    |
# | 37  |                 Trash Bags,  Laundry Detergent                  |   47    |
# | 38  |                              Milk                               |    3    |
# | 39  |                           Trash Bags                            |   59    |
# | 40  |                       Toilet Paper,  Milk                       |    5    |
# | 41  |                         Razors,  Razors                         |   52    |
# | 42  |                            Dog Food                             |   110   |
# | 43  |                       Lotion,  Trash Bags                       |   54    |
# | 44  |                             Lotion                              |    2    |
# | 45  |               Paper Towels,  Paper Towels,  Milk                |    2    |
# | 46  |           Paper Towels,  Paper Towels,  Paper Towels            |    2    |
# | 47  |                   Razors,  Razors,  Dog Food                    |    1    |
# | 48  |                   Paper Towels,  Paper Towels                   |   51    |
# | 49  |                   Razors,  Dog Food,  Razors                    |    3    |
# | 50  |                   Dog Food,  Razors,  Razors                    |    3    |
# | 51  |                      Dog Food,  Trash Bags                      |   58    |
# | 52  |                  Dog Food,  Laundry Detergent                   |    1    |
# | 53  |                 Dog Food,  Lotion,  Trash Bags                  |    4    |
# | 54  |                  Dog Food,  Laundry Detergent                   |   106   |
# | 55  |                      Dog Food,  Trash Bags                      |    3    |
# | 56  |                 Dog Food,  Lotion,  Trash Bags                  |   54    |
# | 57  |            Toilet Paper,  Trash Bags,  Toilet Paper             |   53    |
# | 58  |                          Razors, Milk                           |    1    |
# | 59  |                       Toilet Paper, Milk                        |   56    |
# | 60  |                       Toilet Paper , Milk                       |    1    |
# | 61  |                      Milk,  Razors,  Milk                       |    2    |
# | 62  |                Paper Towels,  Paper Towels, Milk                |   60    |
# | 63  |                       Milk,  Paper Towels                       |   54    |
# | 207 |                       Lotion                       |          Milk,  Lotion, Lotion           |    1.00    |
# | 208 |               Milk,  Lotion,  Lotion               |                  Lotion                  |    1.00    |
# | 209 |                  Lotion,  Lotion                   |              Milk,  Lotion               |    1.00    |
# | 210 |                        Milk                        |    Razors,  Milk ,  Laundry Detergent    |    0.88    |
# | 211 |                Milk,  Razors,  Milk                |            Laundry Detergent             |    1.00    |
# | 212 |              Milk,  Laundry Detergent              |              Razors,  Milk               |    0.96    |
# | 213 |         Razors,  Milk ,  Laundry Detergent         |                   Milk                   |    1.00    |
# | 214 |                Lotion,  Trash Bags                 |     Trash Bags ,  Laundry Detergent      |    0.75    |
# | 215 |         Trash Bags ,  Lotion,  Trash Bags          |            Laundry Detergent             |    1.00    |
# | 216 |          Trash Bags ,  Laundry Detergent           |           Lotion,  Trash Bags            |    1.00    |
# | 217 |      Lotion,  Trash Bags,  Laundry Detergent       |                Trash Bags                |    0.75    |
# +-----+----------------------------------------------------+------------------------------------------+------------+
#
#
# Results for /Users/pradeepvarma/Downloads/dataset/amazon_data.csv:
#
# Frequent Itemsets:
# +-----+-----------------------------------------------------+---------+
# | No. |                  Frequent Itemset                   | Support |
# +-----+-----------------------------------------------------+---------+
# |  1  |                    Sugar, Sugar                     |   57    |
# |  2  |                 Detergent, Tea, Tea                 |    1    |
# |  3  |                   Cheese, Cheese                    |   125   |
# |  4  |            Sugar, Diapers, Cheese, Sugar            |   52    |
# |  5  |      Detergent, Cheese, Sugar, Cheese, Cheese       |    4    |
# |  6  |                      Tea, Tea                       |    4    |
# |  7  |                 Sugar, Sugar, Sugar                 |    6    |
# |  8  |     Detergent, Cheese, Sugar, Cheese, Detergent     |    3    |
# |  9  |                 Flour, Juice, Juice                 |   70    |
# | 10  |       Sugar, Diapers, Cheese, Sugar, Diapers        |    2    |
# | 11  |          Detergent, Cheese, Sugar, Cheese           |   56    |
# | 12  |                       Cheese                        |   49    |
# | 13  |           Diapers, Flour, Cheese, Diapers           |   53    |
# | 14  |            Shampoo, Detergent, Detergent            |   47    |
# | 15  |              Juice, Tea, Juice, Juice               |    3    |
# | 16  |        Detergent, Shampoo, Shampoo, Shampoo         |    2    |
# | 17  |      Shampoo, Detergent, Detergent, Detergent       |    1    |
# | 18  |               Juice, Tea, Juice, Tea                |    3    |
# | 19  |                Flour, Cheese, Flour                 |   62    |
# | 20  |                  Diapers, Diapers                   |   58    |
# | 21  |  Detergent, Shampoo, Tea, Cheese, Shampoo, Cheese   |    1    |
# | 22  |              Detergent, Tea, Detergent              |    3    |
# | 23  |      Detergent, Shampoo, Tea, Cheese, Shampoo       |   47    |
# | 24  |             Detergent, Shampoo, Shampoo             |   45    |
# | 25  |  Detergent, Shampoo, Tea, Cheese, Shampoo, Shampoo  |    3    |
# | 26  |        Sugar, Diapers, Cheese, Sugar, Sugar         |    4    |
# | 27  |            Flour, Cheese, Flour, Cheese             |    3    |
# | 28  |                   Detergent, Tea                    |   44    |
# | 29  |             Flour, Juice, Juice, Flour              |    1    |
# | 30  |      Diapers, Flour, Cheese, Diapers, Diapers       |    3    |
# | 31  |       Diapers, Flour, Cheese, Diapers, Cheese       |    2    |
# | 32  |       Shampoo, Detergent, Detergent, Shampoo        |    2    |
# | 33  |       Detergent, Shampoo, Shampoo, Detergent        |    2    |
# | 34  |             Flour, Cheese, Flour, Flour             |    2    |
# | 35  |                  Juice, Tea, Juice                  |   47    |
# | 36  |                         Tea                         |   115   |
# | 37  |       Diapers, Flour, Cheese, Diapers, Flour        |    2    |
# | 38  |               Cheese, Cheese, Cheese                |   10    |
# | 39  | Detergent, Shampoo, Tea, Cheese, Shampoo, Detergent |    1    |
# | 40  |              Diapers, Diapers, Diapers              |    5    |
# +-----+-----------------------------------------------------+---------+
#
# Association Rules:
# +-----+------------+------------+------------+
# | No. | Antecedent | Consequent | Confidence |
# +-----+------------+------------+------------+
# +-----+------------+------------+------------+
#
#
# Results for /Users/pradeepvarma/Downloads/dataset/best_buy_data.csv:
#
# Frequent Itemsets:
# +-----+-------------------------------------------------------------------------------+---------+
# | No. |                               Frequent Itemset                                | Support |
# +-----+-------------------------------------------------------------------------------+---------+
# |  1  |                                    Router                                     |   120   |
# |  2  |                         Charger,  External Hard Drive                         |    1    |
# |  3  |                                    Printer                                    |   62    |
# |  4  |                     Smartwatch,  Smartwatch,  Smartwatch                      |    2    |
# |  5  |                              Keyboard,  Keyboard                              |   42    |
# |  6  |                              External Hard Drive                              |    2    |
# |  7  |                     Smartphone,  Smartphone,  Smartphone                      |    4    |
# |  8  |                                  Smartwatch                                   |   124   |
# |  9  |                        Keyboard,  Keyboard,  Keyboard                         |    1    |
# | 10  |                                   Keyboard                                    |    5    |
# | 11  |                   Keyboard,  Keyboard,  External Hard Drive                   |    1    |
# | 12  |                         Charger,  Charger,  Keyboard                          |    2    |
# | 13  |                               Charger,  Charger                               |   62    |
# | 14  |                         Printer,  Printer,  Speakers                          |    4    |
# | 15  |                              Keyboard,  Keyboard                              |   105   |
# | 16  |                                    Charger                                    |   105   |
# | 17  |                                  Smartwatch                                   |   47    |
# | 18  |                       Keyboard,  Keyboard,  Smartwatch                        |    3    |
# | 19  |                          Charger,  Charger,  Router                           |    2    |
# | 20  |                            Smartwatch,  Smartwatch                            |   63    |
# | 21  |        External Hard Drive,  External Hard Drive,  External Hard Drive        |   11    |
# | 22  |                            Smartwatch,  Smartwatch                            |   56    |
# | 23  |                              External Hard Drive                              |   113   |
# | 24  |                                    Router                                     |   201   |
# | 25  |                                    Charger                                    |   164   |
# | 26  |                          Charger,  Charger,  Charger                          |    1    |
# | 27  |                                   Speakers                                    |   62    |
# | 28  |                                    Printer                                    |   172   |
# | 29  |                               Printer,  Printer                               |   61    |
# | 30  |                              External Hard Drive                              |   59    |
# | 31  |                          Printer,  Printer,  Printer                          |    5    |
# | 32  |                                  Smartphone                                   |   53    |
# ...
# | 150 |                 First Aid Supplies,  First Aid Supplies                 |                               Band-Aids                               |    1.00    |
# | 151 |                            Insect Repellent                             |                   Thermometer,  First Aid Supplies                    |    0.92    |
# | 152 |                      Thermometer, Insect Repellent                      |                          First Aid Supplies                           |    1.00    |
# | 181 |             Blood Pressure Monitor,  Cold and Flu Medicine              |            Cold and Flu Medicine,  Blood Pressure Monitor             |    0.62    |
# | 182 |  Blood Pressure Monitor,  Cold and Flu Medicine, Cold and Flu Medicine  |                        Blood Pressure Monitor                         |    0.62    |
# | 183 | Blood Pressure Monitor,  Cold and Flu Medicine,  Blood Pressure Monitor |                         Cold and Flu Medicine                         |    1.00    |
# | 184 |             Cold and Flu Medicine,  Blood Pressure Monitor              |            Blood Pressure Monitor,  Cold and Flu Medicine             |    1.00    |
# | 185 |             Blood Pressure Monitor,  Cold and Flu Medicine              |                Insect Repellent, Cold and Flu Medicine                |    1.00    |
# | 186 |    Insect Repellent,  Blood Pressure Monitor,  Cold and Flu Medicine    |                         Cold and Flu Medicine                         |    1.00    |
# | 187 |  Blood Pressure Monitor,  Cold and Flu Medicine, Cold and Flu Medicine  |                           Insect Repellent                            |    1.00    |
# | 188 |                Cold and Flu Medicine,  Insect Repellent                 |                           Insect Repellent                            |    1.00    |
# | 189 |    Blood Pressure Monitor,  Cold and Flu Medicine,  Insect Repellent    |                         Cold and Flu Medicine                         |    1.00    |
# | 190 |                Cold and Flu Medicine,  Insect Repellent                 |            Blood Pressure Monitor,  Cold and Flu Medicine             |    1.00    |
# | 191 |                          Cold and Flu Medicine                          |   Insect Repellent,  Blood Pressure Monitor,  Cold and Flu Medicine   |    1.00    |
# | 192 |                Insect Repellent,  Cold and Flu Medicine                 |            Blood Pressure Monitor,  Cold and Flu Medicine             |    1.00    |
# | 193 | Blood Pressure Monitor,  Cold and Flu Medicine,  Cold and Flu Medicine  |                           Insect Repellent                            |    1.00    |
# | 194 |                   Blood Pressure Monitor,  Band-Aids                    |                         Band-Aids,  Band-Aids                         |    1.00    |
# | 195 |                                Band-Aids                                |            Band-Aids,  Blood Pressure Monitor,  Band-Aids             |    1.00    |
# | 196 |             Band-Aids,  Blood Pressure Monitor,  Band-Aids              |                               Band-Aids                               |    1.00    |
# | 197 |                          Band-Aids,  Band-Aids                          |                  Blood Pressure Monitor,  Band-Aids                   |    1.00    |
# | 198 |             Blood Pressure Monitor,  Band-Aids,  Band-Aids              |                               Band-Aids                               |    1.00    |
# | 199 |                                Band-Aids                                |                   Band-Aids,  Cold and Flu Medicine                   |    1.00    |
# | 200 |                          Band-Aids,  Band-Aids                          |                         Cold and Flu Medicine                         |    1.00    |
# | 201 |                   Band-Aids ,  Cold and Flu Medicine                    |                               Band-Aids                               |    1.00    |
# | 202 |                   Blood Pressure Monitor,  Band-Aids                    |                   Band-Aids,  Cold and Flu Medicine                   |    1.00    |
# | 203 |             Band-Aids,  Blood Pressure Monitor,  Band-Aids              |                         Cold and Flu Medicine                         |    1.00    |
# | 204 |       Blood Pressure Monitor,  Band-Aids,  Cold and Flu Medicine        |                               Band-Aids                               |    1.00    |
# | 205 |                                Band-Aids                                |      Blood Pressure Monitor,  Band-Aids ,  Cold and Flu Medicine      |    0.51    |
# | 206 |                   Blood Pressure Monitor,  Band-Aids                    |                   Band-Aids,  Cold and Flu Medicine                   |    1.00    |
# | 207 |                          Cold and Flu Medicine                          |            Band-Aids,  Blood Pressure Monitor,  Band-Aids             |    0.95    |
# | 208 |             Band-Aids,  Blood Pressure Monitor,  Band-Aids              |                         Cold and Flu Medicine                         |    1.00    |
# | 209 |                    Band-Aids,  Cold and Flu Medicine                    |                  Blood Pressure Monitor,  Band-Aids                   |    0.95    |
# | 210 |       Blood Pressure Monitor,  Band-Aids ,  Cold and Flu Medicine       |                               Band-Aids                               |    1.00    |
# | 211 |             Blood Pressure Monitor,  Cold and Flu Medicine              |               Insect Repellent,  Blood Pressure Monitor               |    0.62    |
# | 212 |    Insect Repellent,  Blood Pressure Monitor,  Cold and Flu Medicine    |                        Blood Pressure Monitor                         |    0.62    |
# | 213 |                Insect Repellent,  Blood Pressure Monitor                |            Blood Pressure Monitor,  Cold and Flu Medicine             |    1.00    |
# | 214 | Blood Pressure Monitor,  Cold and Flu Medicine,  Blood Pressure Monitor |                           Insect Repellent                            |    1.00    |
# | 215 |                   Eye Drops,  Blood Pressure Monitor                    |                        Blood Pressure Monitor                         |    1.00    |
# | 216 |            Blood Pressure Monitor ,  Blood Pressure Monitor             |                               Eye Drops                               |    1.00    |
# | 217 |                   Eye Drops,  Blood Pressure Monitor                    |                        Blood Pressure Monitor                         |    1.00    |
# | 218 |            Blood Pressure Monitor ,  Blood Pressure Monitor             |                               Eye Drops                               |    1.00    |
# | 219 |                   Eye Drops,  Blood Pressure Monitor                    |                               Eye Drops                               |    1.00    |
# | 220 |                   Blood Pressure Monitor,  Band-Aids                    |                  Band-Aids ,  Cold and Flu Medicine                   |    1.00    |
# | 221 |                                Band-Aids                                |      Blood Pressure Monitor,  Band-Aids,  Cold and Flu Medicine       |    1.00    |
# | 222 |             Blood Pressure Monitor,  Band-Aids,  Band-Aids              |                         Cold and Flu Medicine                         |    1.00    |
# | 223 |       Blood Pressure Monitor,  Band-Aids,  Cold and Flu Medicine        |                               Band-Aids                               |    1.00    |
# | 224 |                   Band-Aids ,  Cold and Flu Medicine                    |                  Blood Pressure Monitor,  Band-Aids                   |    1.00    |
# | 225 |    Blood Pressure Monitor,  Cold and Flu Medicine,  Insect Repellent    |                           Insect Repellent                            |    1.00    |
# | 226 |                  First Aid Supplies,  Insect Repellent                  |                     Insect Repellent,  Band-Aids                      |    1.00    |
# | 227 |                                Band-Aids                                |       Insect Repellent,  First Aid Supplies,  Insect Repellent        |    0.91    |
# | 228 |        Insect Repellent,  First Aid Supplies,  Insect Repellent         |                               Band-Aids                               |    1.00    |
# | 229 |                      Insect Repellent,  Band-Aids                       |                 First Aid Supplies,  Insect Repellent                 |    0.92    |
# | 230 |            Band-Aids,  First Aid Supplies,  Insect Repellent            |                           Insect Repellent                            |    1.00    |
# | 231 |                      Band-Aids,  Insect Repellent                       |                           Insect Repellent                            |    1.00    |
# | 232 |                  First Aid Supplies,  Insect Repellent                  |                     Insect Repellent,  Band-Aids                      |    1.00    |
# | 233 |        Insect Repellent,  First Aid Supplies,  Insect Repellent         |                               Band-Aids                               |    1.00    |
# | 234 |            Band-Aids,  First Aid Supplies,  Insect Repellent            |                           Insect Repellent                            |    1.00    |
# | 235 |                  First Aid Supplies,  Insect Repellent                  |                  Insect Repellent,  Insect Repellent                  |    0.50    |
# | 236 |        Insect Repellent,  First Aid Supplies,  Insect Repellent         |                           Insect Repellent                            |    0.50    |
# | 237 |        First Aid Supplies,  Insect Repellent,  Insect Repellent         |                           Insect Repellent                            |    1.00    |
# | 238 |                  First Aid Supplies,  Insect Repellent                  |                     Band-Aids,  Insect Repellent                      |    0.50    |
# | 239 |            Band-Aids,  First Aid Supplies,  Insect Repellent            |                           Insect Repellent                            |    0.50    |
# | 240 |                      Band-Aids,  Insect Repellent                       |                 First Aid Supplies,  Insect Repellent                 |    1.00    |
# | 241 |        First Aid Supplies,  Insect Repellent,  Insect Repellent         |                               Band-Aids                               |    1.00    |
# | 242 |                   Eye Drops,  Blood Pressure Monitor                    |                               Eye Drops                               |    1.00    |
# | 243 |                   Eye Drops,  Blood Pressure Monitor                    |                               Eye Drops                               |    1.00    |
# +-----+-------------------------------------------------------------------------+-----------------------------------------------------------------------+------------+
#
#
# Execution Time: 5.5233659744262695

# %% [markdown]
# ## Apriori Algorithm for Transaction Analysis

# %%
import pandas as pd
from time import time
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from tabulate import tabulate

def read_transactions(csv_file):
    transaction_data = pd.read_csv(csv_file)['Filtered Transaction'].str.split(', ').tolist()
    return transaction_data

def perform_analysis(dataset_path, support_threshold, confidence_level):
    tick = time() 
    
    transactions = read_transactions(dataset_path)
    
    # Convert transactions into a one-hot encoded DataFrame
    encoder = TransactionEncoder()
    transaction_matrix = encoder.fit_transform(transactions)
    transaction_df = pd.DataFrame(transaction_matrix, columns=encoder.columns_)
    
    # Generate frequent itemsets using Apriori
    frequent_sets = apriori(transaction_df, min_support=support_threshold, use_colnames=True)
    
    # Derive association rules from the frequent itemsets
    derived_rules = association_rules(frequent_sets, metric="confidence", min_threshold=confidence_level)
    
    dataset_name = dataset_path.split('/')[-1]  # Extracting filename for display
    
    print(f"\nTransactions from {dataset_name}:\n")
    transaction_table = tabulate(transactions, headers=["Transaction Items"], tablefmt="pretty")
    print(transaction_table)
    
    print("\nDerived Association Rules:\n")
    if not derived_rules.empty:
        rules_table = tabulate(
            derived_rules[['antecedents', 'consequents', 'support', 'confidence']].values,
            headers=['Antecedents', 'Consequents', 'Support', 'Confidence'],
            tablefmt='pretty'
        )
        print(rules_table)
    else:
        print("No association rules found for the given parameters.")
    
    tock = time()
    print(f"\nProcessing time for {dataset_name}: {tock - tick:.2f} seconds\n")

def initiate_analysis():
    datasets = [
        "/Users/pradeepvarma/Downloads/dataset/walmart_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/amazon_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/best_buy_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/costco_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/walgreens_data.csv"
    ]
    
    min_support = float(input("Enter minimum support value (e.g., 0.05 for 5%): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5 for 50%): "))

    for path in datasets:
        perform_analysis(path, min_support, min_confidence)

if __name__ == "__main__":
    initiate_analysis()
# Out:
# Enter minimum support value (e.g., 0.05 for 5%): 0.05
# Enter minimum confidence value (e.g., 0.5 for 50%): 0.5
#
# Transactions from walmart_data.csv:
#
# +-------------------+-------------------+
# |                   | Transaction Items |
# +-------------------+-------------------+
# |      Razors       |      Razors       |
# |       Milk        |   Toilet Paper    |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |       Milk        |       Milk        |
# |       Milk        |       Milk        |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |      Lotion       |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |      Razors       |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Paper Towels    |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |       Milk        |       Milk        |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |      Razors       |     Dog Food      |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |      Razors       |
# |     Dog Food      |      Razors       |
# |     Dog Food      |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# |      Lotion       |      Lotion       |
# |     Dog Food      |      Razors       |
# |      Lotion       |       Milk        |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |       Milk        |
# |       Milk        | Laundry Detergent |
# |      Lotion       |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |      Lotion       |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |       Milk        |       Milk        |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |      Razors       |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |      Razors       |      Razors       |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Paper Towels    |
# |   Paper Towels    |   Paper Towels    |
# |      Razors       |      Razors       |
# |       Milk        | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |      Lotion       |
# |      Razors       |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |      Razors       |
# |      Razors       |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# |      Razors       |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |       Milk        |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |       Milk        |
# |     Dog Food      |     Dog Food      |
# |       Milk        | Laundry Detergent |
# |       Milk        | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |      Lotion       |       Milk        |
# |      Lotion       |       Milk        |
# |     Dog Food      |      Razors       |
# |     Dog Food      |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |     Dog Food      |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |      Razors       |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |      Razors       |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |     Dog Food      |      Razors       |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |       Milk        |
# |       Milk        |   Paper Towels    |
# |      Lotion       |      Lotion       |
# |       Milk        |       Milk        |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |      Razors       |     Dog Food      |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |       Milk        |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |      Razors       |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |       Milk        |       Milk        |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |      Razors       |
# |      Lotion       |      Lotion       |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |      Razors       |     Dog Food      |
# | Laundry Detergent | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |       Milk        |       Milk        |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |     Dog Food      |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |     Dog Food      |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |      Razors       |
# |     Dog Food      |     Dog Food      |
# |      Razors       |      Razors       |
# |       Milk        |       Milk        |
# |       Milk        |       Milk        |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      
      Lotion       |
# | Laundry Detergent |    Trash Bags     |
# |      Lotion       |       Milk        |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |      Lotion       |      Lotion       |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |       Milk        |       Milk        |
# |      Lotion       |      Lotion       |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |      Razors       |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |       Milk        |
# |     Dog Food      |      Razors       |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |      Razors       |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# |      Lotion       |       Milk        |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |      Razors       |      Razors       |
# |       Milk        |       Milk        |
# |       Milk        |       Milk        |
# |     Dog Food      |     Dog Food      |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |       Milk        |
# |      Razors       |      Razors       |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |       Milk        |
# |       Milk        | Laundry Detergent |
# |      Razors       |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |     Dog Food      |      Razors       |
# |      Razors       |      Razors       |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |      Lotion       |       Milk        |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |       Milk        |
# |     Dog Food      |     Dog Food      |
# |       Milk        | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |      Razors       |
# |     Dog Food      |      Razors       |
# |       Milk        |   Toilet Paper    |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |      Razors       |     Dog Food      |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |       Milk        |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |      Lotion       |       Milk        |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |       Milk        |
# |      Razors       |     Dog Food      |
# |     Dog Food      |      Razors       |
# |     Dog Food      |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |      Lotion       |
# |   Paper Towels    |   Paper Towels    |
# |   Paper Towels    |   Paper Towels    |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |       Milk        |
# |      Lotion       |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |      Razors       |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# |      Razors       |     Dog Food      |
# |      Razors       |     Dog Food      |
# |       Milk        | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |      Razors       |     Dog Food      |
# |      Lotion       |       Milk        |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |      Razors       |      Razors       |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |       Milk        |
# |      Razors       |     Dog Food      |
# |      Razors       |      Razors       |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |       Milk        |       Milk        |
# |      Lotion       |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |      Razors       |
# |       Milk        |       Milk        |
# |       Milk        |       Milk        |
# |     Dog Food      |    Trash Bags     |
# |      Razors       |     Dog Food      |
# |       Milk        |   Paper Towels    |
# |      Lotion       |      Lotion       |
# |      Razors       |      Razors       |
# |   Paper Towels    |   Paper Towels    |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |      Razors       |      Razors       |
# |      Lotion       |       Milk        |
# |      Razors       |      Razors       |
# |      Razors       |      Razors       |
# |   Toilet Paper    |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |      Razors       |
# |      Razors       |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |      Lotion       |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Paper Towels    |
# |       Milk        | Laundry Detergent |
# |       Milk        | Laundry Detergent |
# |      Lotion       |      Lotion       |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |      Razors       |      Razors       |
# |     Dog Food      |      Razors       |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |      Lotion       |       Milk        |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |      Razors       |     Dog Food      |
# |      Lotion       |      Lotion       |
# |      Lotion       |       Milk        |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |       Milk        |
# |      Lotion       |      Lotion       |
# |       Milk        | Laundry Detergent |
# |      Lotion       |      Lotion       |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Paper Towels    |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |      Razors       |
# |   Paper Towels    |   Paper Towels    |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |       Milk        |
# |       Milk        |   Toilet Paper    |
# |      Razors       |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |     Dog Food      |    Trash Bags     |
# |      Razors       |     Dog Food      |
# |      Razors       |      Razors       |
# |       Milk        |   Toilet Paper    |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |       Milk        |       Milk        |
# |       Milk        |       Milk        |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |      Lotion       |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |      Razors       |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Paper Towels    |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |       Milk        |       Milk        |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# +-------------------+-------------------+
#
# Derived Association Rules:
#
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |                             Antecedents                              |                           Consequents                            | Support |     Confidence     |
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |                       frozenset({' Razors '})                        |                     frozenset({' Dog Food'})                     |  0.053  |        1.0         |
# |                      frozenset({' Dog Food '})                       |                frozenset({' Laundry Detergent '})                |  0.058  | 0.9830508474576273 |
# |                      frozenset({' Dog Food '})                       |                      frozenset({' Lotion'})                      |  0.058  | 0.9830508474576273 |
# |                        frozenset({' Lotion'})                        |                    frozenset({' Dog Food '})                     |  0.058  | 0.5420560747663552 |
# |                      frozenset({' Dog Food '})                       |                   frozenset({' Trash Bags '})                    |  0.058  | 0.9830508474576273 |
# |                     frozenset({' Trash Bags '})                      |                    frozenset({' Dog Food '})                     |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5420560747663552 |
# |                     frozenset({' Trash Bags '})                      |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5087719298245614 |
# |                  frozenset({'Laundry Detergent '})                   |                frozenset({' Laundry Detergent '})                |  0.104  |        1.0         |
# |                     frozenset({' Trash Bags '})                      |                      frozenset({' Lotion'})                      |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |                   frozenset({' Trash Bags '})                    |  0.058  | 0.5420560747663552 |
# |                       frozenset({' Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                     frozenset({' Lotion '})                      |  0.051  |        1.0         |
# |                       frozenset({' Lotion '})                        |                      frozenset({'Lotion '})                      |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                         frozenset({' Milk'})                         |                       frozenset({'Milk'})                        |  0.059  | 0.5363636363636364 |
# |                         frozenset({'Milk'})                          |                       frozenset({' Milk'})                       |  0.059  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |                        frozenset({' Razors'})                        |                      frozenset({' Milk '})                       |  0.106  | 0.5047619047619047 |
# |                        frozenset({' Milk '})                         |                      frozenset({' Razors'})                      |  0.106  | 0.6127167630057804 |
# |                     frozenset({' Toilet Paper'})                     |                      frozenset({' Milk '})                       |  0.065  |        1.0         |
# |                         frozenset({'Milk '})                         |                      frozenset({' Milk '})                       |  0.121  | 0.6612021857923497 |
# |                        frozenset({' Milk '})                         |                       frozenset({'Milk '})                       |  0.121  | 0.6994219653179191 |
# |                     frozenset({' Paper Towels'})                     |                       frozenset({'Milk '})                       |  0.064  | 0.547008547008547  |
# |                     frozenset({'Paper Towels'})                      |                   frozenset({' Paper Towels'})                   |  0.053  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                        frozenset({'Razors'})                         |                      frozenset({' Razors'})                      |  0.05   |        1.0         |
# |                     frozenset({' Toilet Paper'})                     |                       frozenset({'Milk '})                       |  0.065  |        1.0         |
# ...
# |                      frozenset({' Band-Aids ', ' Insect Repellent '})                       |                              frozenset({' Toothpaste '})                               |  0.079  |        1.0         |
# |                      frozenset({' Toothpaste ', ' Insect Repellent '})                      |                               frozenset({' Band-Aids '})                               |  0.079  |        1.0         |
# |                                 frozenset({' Band-Aids '})                                  |                   frozenset({' Toothpaste ', ' Insect Repellent '})                    |  0.079  | 0.5563380281690141 |
# |                                 frozenset({' Toothpaste '})                                 |                    frozenset({' Band-Aids ', ' Insect Repellent '})                    |  0.079  | 0.5602836879432624 |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |                           frozenset({' Insect Repellent '})                            |  0.073  | 0.5367647058823529 |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            |              frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})              |  0.073  | 0.5289855072463767 |
# |                    frozenset({'Band-Aids ', ' Cold and Flu Medicine '})                     |                         frozenset({' Blood Pressure Monitor'})                         |  0.063  |        1.0         |
# |                    frozenset({'Band-Aids ', ' Blood Pressure Monitor'})                     |                         frozenset({' Cold and Flu Medicine '})                         |  0.063  |        1.0         |
# |                                  frozenset({'Band-Aids '})                                  |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.063  | 0.5338983050847458 |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  | 0.9733333333333333 |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  | 0.5367647058823529 |
# |                           frozenset({' Cold and Flu Medicine '})                            |            frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.073  | 0.5289855072463767 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |                           frozenset({' Insect Repellent '})                            |  0.073  |        1.0         |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  |        1.0         |
# |                   frozenset({' Eye Drops ', ' Blood Pressure Monitor '})                    |                               frozenset({'Eye Drops '})                                |  0.055  |        1.0         |
# |                          frozenset({' Eye Drops ', 'Eye Drops '})                           |                        frozenset({' Blood Pressure Monitor '})                         |  0.055  | 0.5288461538461539 |
# |                    frozenset({' Blood Pressure Monitor ', 'Eye Drops '})                    |                               frozenset({' Eye Drops '})                               |  0.055  |        1.0         |
# |                                  frozenset({'Eye Drops '})                                  |                 frozenset({' Eye Drops ', ' Blood Pressure Monitor '})                 |  0.055  | 0.5288461538461539 |
# |                   frozenset({' Thermometer', ' Blood Pressure Monitor '})                   |                         frozenset({'Blood Pressure Monitor '})                         |  0.058  |        1.0         |
# |                   frozenset({' Thermometer', 'Blood Pressure Monitor '})                    |                        frozenset({' Blood Pressure Monitor '})                         |  0.058  |        1.0         |
# |             frozenset({' Blood Pressure Monitor ', 'Blood Pressure Monitor '})              |                              frozenset({' Thermometer'})                               |  0.058  | 0.9206349206349207 |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |                           frozenset({' Insect Repellent '})                            |  0.073  | 0.9733333333333333 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            |              frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})               |  0.073  | 0.5289855072463767 |
# |                     frozenset({' First Aid Supplies', ' Toothpaste '})                      |                           frozenset({' Insect Repellent '})                            |  0.079  |        1.0         |
# |                  frozenset({' First Aid Supplies', ' Insect Repellent '})                   |                              frozenset({' Toothpaste '})                               |  0.079  |        1.0         |
# |                      frozenset({' Toothpaste ', ' Insect Repellent '})                      |                           frozenset({' First Aid Supplies'})                           |  0.079  |        1.0         |
# |                             frozenset({' First Aid Supplies'})                              |                   frozenset({' Toothpaste ', ' Insect Repellent '})                    |  0.079  | 0.5448275862068966 |
# |                                 frozenset({' Toothpaste '})                                 |                frozenset({' First Aid Supplies', ' Insect Repellent '})                |  0.079  | 0.5602836879432624 |
# |                     frozenset({' Thermometer', ' First Aid Supplies '})                     |                            frozenset({'Insect Repellent '})                            |  0.05   | 0.9803921568627452 |
# |                      frozenset({' Thermometer', 'Insect Repellent '})                       |                          frozenset({' First Aid Supplies '})                           |  0.05   |        1.0         |
# |                  frozenset({' First Aid Supplies ', 'Insect Repellent '})                   |                              frozenset({' Thermometer'})                               |  0.05   |        1.0         |
# |                              frozenset({'Insect Repellent '})                               |                  frozenset({' Thermometer', ' First Aid Supplies '})                   |  0.05   |        1.0         |
# |             frozenset({' Band-Aids ', 'Band-Aids ', ' Cold and Flu Medicine '})             |                         frozenset({' Blood Pressure Monitor'})                         |  0.063  |        1.0         |
# |             frozenset({' Band-Aids ', 'Band-Aids ', ' Blood Pressure Monitor'})             |                         frozenset({' Cold and Flu Medicine '})                         |  0.063  |        1.0         |
# |      frozenset({' Band-Aids ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'})       |                               frozenset({'Band-Aids '})                                |  0.063  |        1.0         |
# |       frozenset({'Band-Aids ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'})       |                               frozenset({' Band-Aids '})                               |  0.063  |        1.0         |
# |                          frozenset({' Band-Aids ', 'Band-Aids '})                           |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.063  |        1.0         |
# |                    frozenset({' Band-Aids ', ' Cold and Flu Medicine '})                    |                  frozenset({'Band-Aids ', ' Blood Pressure Monitor'})                  |  0.063  |        1.0         |
# |                    frozenset({' Band-Aids ', ' Blood Pressure Monitor'})                    |                  frozenset({'Band-Aids ', ' Cold and Flu Medicine '})                  |  0.063  |        1.0         |
# |                    frozenset({'Band-Aids ', ' Cold and Flu Medicine '})                     |                 frozenset({' Band-Aids ', ' Blood Pressure Monitor'})                  |  0.063  |        1.0         |
# |                    frozenset({'Band-Aids ', ' Blood Pressure Monitor'})                     |                 frozenset({' Band-Aids ', ' Cold and Flu Medicine '})                  |  0.063  |        1.0         |
# |                                  frozenset({'Band-Aids '})                                  |    frozenset({' Band-Aids ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'})    |  0.063  | 0.5338983050847458 |
# |              frozenset({' Band-Aids ', ' First Aid Supplies', ' Toothpaste '})              |                           frozenset({' Insect Repellent '})                            |  0.079  |        1.0         |
# |           frozenset({' Band-Aids ', ' First Aid Supplies', ' Insect Repellent '})           |                              frozenset({' Toothpaste '})                               |  0.079  |        1.0         |
# |          frozenset({' First Aid Supplies', ' Toothpaste ', ' Insect Repellent '})           |                               frozenset({' Band-Aids '})                               |  0.079  |        1.0         |
# |              frozenset({' Band-Aids ', ' Toothpaste ', ' Insect Repellent '})               |                           frozenset({' First Aid Supplies'})                           |  0.079  |        1.0         |
# |                      frozenset({' Band-Aids ', ' First Aid Supplies'})                      |                   frozenset({' Toothpaste ', ' Insect Repellent '})                    |  0.079  |        1.0         |
# |                     frozenset({' First Aid Supplies', ' Toothpaste '})                      |                    frozenset({' Band-Aids ', ' Insect Repellent '})                    |  0.079  |        1.0         |
# |                  frozenset({' First Aid Supplies', ' Insect Repellent '})                   |                       frozenset({' Band-Aids ', ' Toothpaste '})                       |  0.079  |        1.0         |
# |                         frozenset({' Band-Aids ', ' Toothpaste '})                          |                frozenset({' First Aid Supplies', ' Insect Repellent '})                |  0.079  |        1.0         |
# |                      frozenset({' Band-Aids ', ' Insect Repellent '})                       |                   frozenset({' First Aid Supplies', ' Toothpaste '})                   |  0.079  |        1.0         |
# |                      frozenset({' Toothpaste ', ' Insect Repellent '})                      |                   frozenset({' Band-Aids ', ' First Aid Supplies'})                    |  0.079  |        1.0         |
# |                             frozenset({' First Aid Supplies'})                              |            frozenset({' Band-Aids ', ' Toothpaste ', ' Insect Repellent '})            |  0.079  | 0.5448275862068966 |
# |                                 frozenset({' Band-Aids '})                                  |        frozenset({' First Aid Supplies', ' Toothpaste ', ' Insect Repellent '})        |  0.079  | 0.5563380281690141 |
# |                                 frozenset({' Toothpaste '})                                 |        frozenset({' Band-Aids ', ' First Aid Supplies', ' Insect Repellent '})         |  0.079  | 0.5602836879432624 |
# |   frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine ', ' Insect Repellent '})    |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  |        1.0         |
# | frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'}) |                           frozenset({' Insect Repellent '})                            |  0.073  |        1.0         |
# |   frozenset({'Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'})    |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |   frozenset({' Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'})   |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |              frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})              |  0.073  | 0.9733333333333333 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.073  |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |              frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})              |  0.073  |        1.0         |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |            frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.073  |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |              frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})               |  0.073  | 0.5367647058823529 |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |            frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})            |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            | frozenset({'Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'}) |  0.073  | 0.5289855072463767 |
# +---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------+--------------------+
#
# Processing time for walgreens_data.csv: 0.03 seconds

# %%
import pandas as pd
from time import time
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from tabulate import tabulate

def load_and_filter_tx(file, min_items=2):
    df = pd.read_csv(file)
    
    txs = df['Filtered Transaction'].apply(lambda x: x.split(', '))
    filtered_txs = [tx for tx in txs if len(tx) >= min_items]
    return filtered_txs

def analyze_data(file, min_sup, min_conf):
    start = time()  # Start timing

    txs = load_and_filter_tx(file)
    
    enc = TransactionEncoder()
    tx_array = enc.fit(txs).transform(txs)
    tx_df = pd.DataFrame(tx_array, columns=enc.columns_)
    
    freq_sets = apriori(tx_df, min_support=min_sup, use_colnames=True)
    ass_rules = association_rules(freq_sets, metric="confidence", min_threshold=min_conf)
    
    print(f"\nFiltered Transactions for {file.split('/')[-1]}:\n")
    tx_table = tabulate(txs, headers=["Transaction Items"], tablefmt="pretty")
    print(tx_table)
    
    print("\nGenerated Association Rules:\n")
    if not ass_rules.empty:
        rules_table = tabulate(
            ass_rules[['antecedents', 'consequents', 'support', 'confidence']].values,
            headers=['Antecedents', 'Consequents', 'Support', 'Confidence'],
            tablefmt='pretty'
        )
        print(rules_table)
    else:
        print("No association rules found for the given parameters.")
    
    print(f"\nTime taken for {file.split('/')[-1]}: {time() - start:.2f} seconds\n")

def run_analysis():
    datasets = {
        1: '/Users/pradeepvarma/Downloads/dataset/walmart_data.csv',
        2: '/Users/pradeepvarma/Downloads/dataset/amazon_data.csv',
        3: '/Users/pradeepvarma/Downloads/dataset/best_buy_data.csv',
        4: '/Users/pradeepvarma/Downloads/dataset/costco_data.csv',
        5: '/Users/pradeepvarma/Downloads/dataset/walgreens_data.csv',
    }
    
    print("Select dataset(s):")
    for k, v in datasets.items():
        print(f"{k} - {v.split('/')[-1]}")
    
    choices = input("Choices (e.g., 1,3): ").split(',')
    min_sup = float(input("Minimum support (e.g., 0.05): "))
    min_conf = float(input("Minimum confidence (e.g., 0.5): "))

    for choice in choices:
        analyze_data(datasets[int(choice)], min_sup, min_conf)

if __name__ == "__main__":
    run_analysis()
# Out:
# Select dataset(s):
# 1 - walmart_data.csv
# 2 - amazon_data.csv
# 3 - best_buy_data.csv
# 4 - costco_data.csv
# 5 - walgreens_data.csv
# Choices (e.g., 1,3): 1,3,5
# Minimum support (e.g., 0.05): 0.05
# Minimum confidence (e.g., 0.5): 0.5
#
# Filtered Transactions for walmart_data.csv:
#
# +-------------------+-------------------+
# |                   | Transaction Items |
# +-------------------+-------------------+
# |      Razors       |      Razors       |
# |       Milk        |   Toilet Paper    |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |       Milk        |       Milk        |
# |       Milk        |       Milk        |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |      Lotion       |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |      Razors       |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |      Lotion       |      Lotion       |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Paper Towels    |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |       Milk        |       Milk        |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |      Razors       |     Dog Food      |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |    Trash Bags     |
# |   Toilet Paper    |    Trash Bags     |
# |     Dog Food      |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |      Razors       |
# |     Dog Food      |      Razors       |
# |     Dog Food      |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |   Paper Towels    |   Paper Towels    |
# |      Lotion       |      Lotion       |
# |     Dog Food      |      Razors       |
# |      Lotion       |       Milk        |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |      Lotion       |       Milk        |
# |       Milk        |       Milk        |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |       Milk        | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |   Toilet Paper    |    Trash Bags     |
# |      Lotion       |       Milk        |
# |       Milk        | Laundry Detergent |
# |      Lotion       |       Milk        |
# |   Paper Towels    |   Paper Towels    |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |      Razors       |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |      Razors       |      Razors       |
# | Laundry Detergent |     Dog Food      |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |      Lotion       |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |      Lotion       |      Lotion       |
# |     Dog Food      |      Razors       |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# |       Milk        |   Paper Towels    |
# |       Milk        |       Milk        |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent |     Dog Food      |
# | Laundry Detergent |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |      Razors       |      Razors       |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        | Laundry Detergent |
# |     Dog Food      |    Trash Bags     |
# |      Lotion       |       Milk        |
# |   Toilet Paper    |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# | Laundry Detergent | Laundry Detergent |
# |      Razors       |      Razors       |
# |       Milk        |   Paper Towels    |
# | Laundry Detergent |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |       Milk        |   Toilet Paper    |
# |       Milk        |   Paper Towels    |
# |   Paper Towels    |   Paper Towels    |
# |      Razors       |      Razors       |
# |       Milk        | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |     Dog Food      |     Dog Food      |
# |      Razors       |      Razors       |
# |     Dog Food      |     Dog Food      |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |     Dog Food      |
# |      Lotion       |      Lotion       |
# |      Razors       |     Dog Food      |
# |     Dog Food      |     Dog Food      |
# |     Dog Food      |      Razors       |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent |    Trash Bags     |
# |       Milk        |   Toilet Paper    |
# |     Dog Food      |      Razors       |
# |      Razors       |     Dog Food      |
# |   Paper Towels    |   Paper Towels    |
# |     Dog Food      |    Trash Bags     |
# |      Razors       |     Dog Food      |
# |   Toilet Paper    |    Trash Bags     |
# |       Milk        |       Milk        |
# |       Milk        |   Toilet Paper    |
# | Laundry Detergent | Laundry Detergent |
# | Laundry Detergent | Laundry Detergent |
# |       Milk        |   Paper Towels    |
# |      Razors       |     Dog Food      |
# +-------------------+-------------------+
#
# Generated Association Rules:
#
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |                             Antecedents                              |                           Consequents                            | Support |     Confidence     |
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |                       frozenset({' Razors '})                        |                     frozenset({' Dog Food'})                     |  0.053  |        1.0         |
# |                      frozenset({' Dog Food '})                       |                frozenset({' Laundry Detergent '})                |  0.058  | 0.9830508474576273 |
# |                      frozenset({' Dog Food '})                       |                      frozenset({' Lotion'})                      |  0.058  | 0.9830508474576273 |
# |                        frozenset({' Lotion'})                        |                    frozenset({' Dog Food '})                     |  0.058  | 0.5420560747663552 |
# |                      frozenset({' Dog Food '})                       |                   frozenset({' Trash Bags '})                    |  0.058  | 0.9830508474576273 |
# |                     frozenset({' Trash Bags '})                      |                    frozenset({' Dog Food '})                     |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5420560747663552 |
# |                     frozenset({' Trash Bags '})                      |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5087719298245614 |
# |                  frozenset({'Laundry Detergent '})                   |                frozenset({' Laundry Detergent '})                |  0.104  |        1.0         |
# |                     frozenset({' Trash Bags '})                      |                      frozenset({' Lotion'})                      |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |                   frozenset({' Trash Bags '})                    |  0.058  | 0.5420560747663552 |
# |                       frozenset({' Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                     frozenset({' Lotion '})                      |  0.051  |        1.0         |
# |                       frozenset({' Lotion '})                        |                      frozenset({'Lotion '})                      |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                         frozenset({' Milk'})                         |                       frozenset({'Milk'})                        |  0.059  | 0.5363636363636364 |
# |                         frozenset({'Milk'})                          |                       frozenset({' Milk'})                       |  0.059  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |                        frozenset({' Razors'})                        |                      frozenset({' Milk '})                       |  0.106  | 0.5047619047619047 |
# |                        frozenset({' Milk '})                         |                      frozenset({' Razors'})                      |  0.106  | 0.6127167630057804 |
# |                     frozenset({' Toilet Paper'})                     |                      frozenset({' Milk '})                       |  0.065  |        1.0         |
# |                         frozenset({'Milk '})                         |                      frozenset({' Milk '})                       |  0.121  | 0.6612021857923497 |
# |                        frozenset({' Milk '})                         |                       frozenset({'Milk '})                       |  0.121  | 0.6994219653179191 |
# |                     frozenset({' Paper Towels'})                     |                       frozenset({'Milk '})                       |  0.064  | 0.547008547008547  |
# |                     frozenset({'Paper Towels'})                      |                   frozenset({' Paper Towels'})                   |  0.053  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                        frozenset({'Razors'})                         |                      frozenset({' Razors'})                      |  0.05   |        1.0         |
# ...
# |                           frozenset({' Cold and Flu Medicine '})                            |              frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})              | 0.08276643990929705 | 0.5289855072463768 |
# |                    frozenset({'Band-Aids ', ' Cold and Flu Medicine '})                     |                         frozenset({' Blood Pressure Monitor'})                         | 0.07142857142857142 |        1.0         |
# |                    frozenset({'Band-Aids ', ' Blood Pressure Monitor'})                     |                         frozenset({' Cold and Flu Medicine '})                         | 0.07142857142857142 |        1.0         |
# |                                  frozenset({'Band-Aids '})                                  |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            | 0.07142857142857142 | 0.5338983050847458 |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |                         frozenset({' Blood Pressure Monitor'})                         | 0.08276643990929705 | 0.9733333333333334 |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |                         frozenset({' Cold and Flu Medicine '})                         | 0.08276643990929705 |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |                         frozenset({'Cold and Flu Medicine '})                          | 0.08276643990929705 | 0.5367647058823529 |
# |                           frozenset({' Cold and Flu Medicine '})                            |            frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})            | 0.08276643990929705 | 0.5289855072463768 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Blood Pressure Monitor'})                         | 0.08276643990929705 |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |                           frozenset({' Insect Repellent '})                            | 0.08276643990929705 |        1.0         |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |                         frozenset({'Cold and Flu Medicine '})                          | 0.08276643990929705 |        1.0         |
# |                   frozenset({' Eye Drops ', ' Blood Pressure Monitor '})                    |                               frozenset({'Eye Drops '})                                | 0.06235827664399093 |        1.0         |
# |                          frozenset({' Eye Drops ', 'Eye Drops '})                           |                        frozenset({' Blood Pressure Monitor '})                         | 0.06235827664399093 | 0.5288461538461539 |
# |                    frozenset({' Blood Pressure Monitor ', 'Eye Drops '})                    |                               frozenset({' Eye Drops '})                               | 0.06235827664399093 |        1.0         |
# |                                  frozenset({'Eye Drops '})                                  |                 frozenset({' Eye Drops ', ' Blood Pressure Monitor '})                 | 0.06235827664399093 | 0.5288461538461539 |
# |                   frozenset({' Thermometer', ' Blood Pressure Monitor '})                   |                         frozenset({'Blood Pressure Monitor '})                         | 0.06575963718820861 |        1.0         |
# |                   frozenset({' Thermometer', 'Blood Pressure Monitor '})                    |                        frozenset({' Blood Pressure Monitor '})                         | 0.06575963718820861 |        1.0         |
# |             frozenset({' Blood Pressure Monitor ', 'Blood Pressure Monitor '})              |                              frozenset({' Thermometer'})                               | 0.06575963718820861 | 0.9206349206349206 |
# |                           frozenset({'Blood Pressure Monitor '})                            |                frozenset({' Thermometer', ' Blood Pressure Monitor '})                 | 0.06575963718820861 | 0.9206349206349206 |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |                           frozenset({' Insect Repellent '})                            | 0.08276643990929705 | 0.9733333333333334 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Cold and Flu Medicine '})                         | 0.08276643990929705 |        1.0         |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({'Cold and Flu Medicine '})                          | 0.08276643990929705 |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            |              frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})               | 0.08276643990929705 | 0.5289855072463768 |
# |                     frozenset({' First Aid Supplies', ' Toothpaste '})                      |                           frozenset({' Insect Repellent '})                            | 0.08956916099773243 |        1.0         |
# |                  frozenset({' First Aid Supplies', ' Insect Repellent '})                   |                              frozenset({' Toothpaste '})                               | 0.08956916099773243 |        1.0         |
# |                      frozenset({' Toothpaste ', ' Insect Repellent '})                      |                           frozenset({' First Aid Supplies'})                           | 0.08956916099773243 |        1.0         |
# |                             frozenset({' First Aid Supplies'})                              |                   frozenset({' Toothpaste ', ' Insect Repellent '})                    | 0.08956916099773243 | 0.5448275862068965 |
# |                                 frozenset({' Toothpaste '})                                 |                frozenset({' First Aid Supplies', ' Insect Repellent '})                | 0.08956916099773243 | 0.5602836879432624 |
# |                              frozenset({' Insect Repellent '})                              |                   frozenset({' First Aid Supplies', ' Toothpaste '})                   | 0.08956916099773243 | 0.5031847133757963 |
# |                     frozenset({' Thermometer', ' First Aid Supplies '})                     |                            frozenset({'Insect Repellent '})                            | 0.05668934240362812 | 0.9803921568627452 |
# |                      frozenset({' Thermometer', 'Insect Repellent '})                       |                          frozenset({' First Aid Supplies '})                           | 0.05668934240362812 |        1.0         |
# |                  frozenset({' First Aid Supplies ', 'Insect Repellent '})                   |                              frozenset({' Thermometer'})                               | 0.05668934240362812 |        1.0         |
# |                              frozenset({'Insect Repellent '})                               |                  frozenset({' Thermometer', ' First Aid Supplies '})                   | 0.05668934240362812 |        1.0         |
# |             frozenset({' Band-Aids ', 'Band-Aids ', ' Cold and Flu Medicine '})             |                         frozenset({' Blood Pressure Monitor'})                         | 0.07142857142857142 |        1.0         |
# |             frozenset({' Band-Aids ', 'Band-Aids ', ' Blood Pressure Monitor'})             |                         frozenset({' Cold and Flu Medicine '})                         | 0.07142857142857142 |        1.0         |
# |      frozenset({' Band-Aids ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'})       |                               frozenset({'Band-Aids '})                                | 0.07142857142857142 |        1.0         |
# |       frozenset({'Band-Aids ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'})       |                               frozenset({' Band-Aids '})                               | 0.07142857142857142 |        1.0         |
# |                          frozenset({' Band-Aids ', 'Band-Aids '})                           |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            | 0.07142857142857142 |        1.0         |
# |                    frozenset({' Band-Aids ', ' Cold and Flu Medicine '})                    |                  frozenset({'Band-Aids ', ' Blood Pressure Monitor'})                  | 0.07142857142857142 |        1.0         |
# |                    frozenset({' Band-Aids ', ' Blood Pressure Monitor'})                    |                  frozenset({'Band-Aids ', ' Cold and Flu Medicine '})                  | 0.07142857142857142 |        1.0         |
# |                    frozenset({'Band-Aids ', ' Cold and Flu Medicine '})                     |                 frozenset({' Band-Aids ', ' Blood Pressure Monitor'})                  | 0.07142857142857142 |        1.0         |
# |                    frozenset({'Band-Aids ', ' Blood Pressure Monitor'})                     |                 frozenset({' Band-Aids ', ' Cold and Flu Medicine '})                  | 0.07142857142857142 |        1.0         |
# |                                  frozenset({'Band-Aids '})                                  |    frozenset({' Band-Aids ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'})    | 0.07142857142857142 | 0.5338983050847458 |
# |              frozenset({' Band-Aids ', ' First Aid Supplies', ' Toothpaste '})              |                           frozenset({' Insect Repellent '})                            | 0.08956916099773243 |        1.0         |
# |           frozenset({' Band-Aids ', ' First Aid Supplies', ' Insect Repellent '})           |                              frozenset({' Toothpaste '})                               | 0.08956916099773243 |        1.0         |
# |          frozenset({' First Aid Supplies', ' Toothpaste ', ' Insect Repellent '})           |                               frozenset({' Band-Aids '})                               | 0.08956916099773243 |        1.0         |
# |              frozenset({' Band-Aids ', ' Toothpaste ', ' Insect Repellent '})               |                           frozenset({' First Aid Supplies'})                           | 0.08956916099773243 |        1.0         |
# |                      frozenset({' Band-Aids ', ' First Aid Supplies'})                      |                   frozenset({' Toothpaste ', ' Insect Repellent '})                    | 0.08956916099773243 |        1.0         |
# |                     frozenset({' First Aid Supplies', ' Toothpaste '})                      |                    frozenset({' Band-Aids ', ' Insect Repellent '})                    | 0.08956916099773243 |        1.0         |
# |                  frozenset({' First Aid Supplies', ' Insect Repellent '})                   |                       frozenset({' Band-Aids ', ' Toothpaste '})                       | 0.08956916099773243 |        1.0         |
# |                         frozenset({' Band-Aids ', ' Toothpaste '})                          |                frozenset({' First Aid Supplies', ' Insect Repellent '})                | 0.08956916099773243 |        1.0         |
# |                      frozenset({' Band-Aids ', ' Insect Repellent '})                       |                   frozenset({' First Aid Supplies', ' Toothpaste '})                   | 0.08956916099773243 |        1.0         |
# |                      frozenset({' Toothpaste ', ' Insect Repellent '})                      |                   frozenset({' Band-Aids ', ' First Aid Supplies'})                    | 0.08956916099773243 |        1.0         |
# |                             frozenset({' First Aid Supplies'})                              |            frozenset({' Band-Aids ', ' Toothpaste ', ' Insect Repellent '})            | 0.08956916099773243 | 0.5448275862068965 |
# |                                 frozenset({' Band-Aids '})                                  |        frozenset({' First Aid Supplies', ' Toothpaste ', ' Insect Repellent '})        | 0.08956916099773243 | 0.5563380281690141 |
# |                                 frozenset({' Toothpaste '})                                 |        frozenset({' Band-Aids ', ' First Aid Supplies', ' Insect Repellent '})         | 0.08956916099773243 | 0.5602836879432624 |
# |                              frozenset({' Insect Repellent '})                              |           frozenset({' Band-Aids ', ' First Aid Supplies', ' Toothpaste '})            | 0.08956916099773243 | 0.5031847133757963 |
# |   frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine ', ' Insect Repellent '})    |                         frozenset({' Blood Pressure Monitor'})                         | 0.08276643990929705 |        1.0         |
# | frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'}) |                           frozenset({' Insect Repellent '})                            | 0.08276643990929705 |        1.0         |
# |   frozenset({'Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'})    |                         frozenset({' Cold and Flu Medicine '})                         | 0.08276643990929705 |        1.0         |
# |   frozenset({' Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'})   |                         frozenset({'Cold and Flu Medicine '})                          | 0.08276643990929705 |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |              frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})              | 0.08276643990929705 | 0.9733333333333334 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            | 0.08276643990929705 |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |              frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})              | 0.08276643990929705 |        1.0         |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |            frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})            | 0.08276643990929705 |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |              frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})               | 0.08276643990929705 | 0.5367647058823529 |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |            frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})            | 0.08276643990929705 |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            | frozenset({'Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'}) | 0.08276643990929705 | 0.5289855072463768 |
# +---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------------------+--------------------+
#
# Time taken for walgreens_data.csv: 0.03 seconds

# %% [markdown]
# ## FP-Growth Algorithm for Transaction Analysis

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
from tabulate import tabulate

def fetch_transactions(csv_path):
    data = pd.read_csv(csv_path)['Filtered Transaction'].str.split(', ').tolist()
    return data

def fp_growth_analysis(csv_path, support_level, confidence_level):
    transactions = fetch_transactions(csv_path)
    
    # Encode the transactions into a one-hot encoded DataFrame
    encoder = TransactionEncoder()
    encoded_data = encoder.fit(transactions).transform(transactions)
    df_encoded = pd.DataFrame(encoded_data, columns=encoder.columns_)
    
    # Generate frequent itemsets using FP-Growth
    itemsets = fpgrowth(df_encoded, min_support=support_level, use_colnames=True)
    
    # Derive association rules from the frequent itemsets
    rules = association_rules(itemsets, metric="confidence", min_threshold=confidence_level)
    
    print(f"\nFrequent Itemsets from {csv_path.split('/')[-1]}:\n")
    if not itemsets.empty:
        itemsets_table = tabulate(
            itemsets[['itemsets', 'support']].values,
            headers=['Itemsets', 'Support'],
            tablefmt='pretty'
        )
        print(itemsets_table)
    else:
        print("No frequent itemsets found for the given parameters.")
    
    print("\nDerived Association Rules:\n")
    if not rules.empty:
        rules_table = tabulate(
            rules[['antecedents', 'consequents', 'support', 'confidence']].values,
            headers=['Antecedents', 'Consequents', 'Support', 'Confidence'],
            tablefmt='pretty'
        )
        print(rules_table)
    else:
        print("No association rules found for the given parameters.")
    print("\n")

def run_analysis():
    dataset_paths = [        
        "/Users/pradeepvarma/Downloads/dataset/walmart_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/amazon_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/best_buy_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/costco_data.csv",
        "/Users/pradeepvarma/Downloads/dataset/walgreens_data.csv"
    ]
    
    min_support = float(input("Enter minimum support value (e.g., 0.05 for 5%): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5 for 50%): "))
    
    for path in dataset_paths:
        fp_growth_analysis(path, min_support, min_confidence)

if __name__ == "__main__":
    run_analysis()
# Out:
# Enter minimum support value (e.g., 0.05 for 5%): 0.05
# Enter minimum confidence value (e.g., 0.5 for 50%): 0.5
#
# Frequent Itemsets from walmart_data.csv:
#
# +-------------------------------------------------------------------------------+---------+
# |                                   Itemsets                                    | Support |
# +-------------------------------------------------------------------------------+---------+
# |                            frozenset({' Razors'})                             |  0.21   |
# |                             frozenset({'Razors'})                             |  0.05   |
# |                             frozenset({'Milk '})                              |  0.183  |
# |                             frozenset({' Milk '})                             |  0.173  |
# |                         frozenset({' Toilet Paper'})                          |  0.065  |
# |                         frozenset({' Toilet Paper '})                         |  0.113  |
# |                          frozenset({' Trash Bags'})                           |  0.109  |
# |                            frozenset({' Lotion'})                             |  0.107  |
# |                      frozenset({' Laundry Detergent '})                       |  0.267  |
# |                          frozenset({' Trash Bags '})                          |  0.114  |
# |                           frozenset({' Dog Food '})                           |  0.059  |
# |                             frozenset({' Milk'})                              |  0.11   |
# |                              frozenset({'Milk'})                              |  0.059  |
# |                       frozenset({'Laundry Detergent '})                       |  0.104  |
# |                         frozenset({' Paper Towels'})                          |  0.117  |
# |                          frozenset({'Paper Towels'})                          |  0.053  |
# |                           frozenset({' Dog Food'})                            |  0.172  |
# |                           frozenset({'Dog Food '})                            |  0.11   |
# |                         frozenset({' Paper Towels '})                         |  0.054  |
# |                            frozenset({' Lotion '})                            |  0.051  |
# |                            frozenset({'Lotion '})                             |  0.051  |
# |                            frozenset({' Razors '})                            |  0.053  |
# |                 frozenset({' Razors', ' Laundry Detergent '})                 |  0.052  |
# |                       frozenset({' Razors', 'Razors'})                        |  0.05   |
# |                        frozenset({' Razors', 'Milk '})                        |  0.054  |
# |                        frozenset({'Milk ', ' Milk '})                         |  0.121  |
# |                       frozenset({' Razors', ' Milk '})                        |  0.106  |
# |                 frozenset({' Laundry Detergent ', ' Milk '})                  |  0.052  |
# |                   frozenset({' Razors', 'Milk ', ' Milk '})                   |  0.054  |
# |            frozenset({' Razors', ' Milk ', ' Laundry Detergent '})            |  0.052  |
# |                    frozenset({' Toilet Paper', ' Milk '})                     |  0.065  |
# |                     frozenset({'Milk ', ' Toilet Paper'})                     |  0.065  |
# |                frozenset({'Milk ', ' Toilet Paper', ' Milk '})                |  0.065  |
# |                    frozenset({' Milk ', ' Toilet Paper '})                    |  0.054  |
# |                    frozenset({'Milk ', ' Toilet Paper '})                     |  0.054  |
# |                   frozenset({' Razors', ' Toilet Paper '})                    |  0.054  |
# |               frozenset({'Milk ', ' Toilet Paper ', ' Milk '})                |  0.054  |
# |              frozenset({' Razors', ' Milk ', ' Toilet Paper '})               |  0.054  |
# |               frozenset({' Razors', 'Milk ', ' Toilet Paper '})               |  0.054  |
# |          frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Milk '})          |  0.054  |
# |                 frozenset({' Toilet Paper ', ' Trash Bags'})                  |  0.059  |
# |               frozenset({' Laundry Detergent ', ' Trash Bags'})               |  0.05   |
# |                    frozenset({' Trash Bags ', ' Lotion'})                     |  0.058  |
# |                 frozenset({' Laundry Detergent ', ' Lotion'})                 |  0.058  |
# |         frozenset({' Laundry Detergent ', ' Trash Bags ', ' Lotion'})         |  0.058  |
# |              frozenset({' Laundry Detergent ', ' Trash Bags '})               |  0.058  |
# |                     frozenset({' Dog Food ', ' Lotion'})                      |  0.058  |
# |                   frozenset({' Dog Food ', ' Trash Bags '})                   |  0.058  |
# |               frozenset({' Laundry Detergent ', ' Dog Food '})                |  0.058  |
# |             frozenset({' Dog Food ', ' Trash Bags ', ' Lotion'})              |  0.058  |
# |          frozenset({' Laundry Detergent ', ' Dog Food ', ' Lotion'})          |  0.058  |
# |       frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags '})        |  0.058  |
# |  frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags ', ' Lotion'})  |  0.058  |
# |                         frozenset({' Milk', 'Milk'})                          |  0.059  |
# |           frozenset({'Laundry Detergent ', ' Laundry Detergent '})            |  0.104  |
# |               frozenset({'Laundry Detergent ', ' Trash Bags'})                |  0.05   |
# |    frozenset({'Laundry Detergent ', ' Laundry Detergent ', ' Trash Bags'})    |  0.05   |
# |                     frozenset({'Milk ', ' Paper Towels'})                     |  0.064  |
# |                 frozenset({'Paper Towels', ' Paper Towels'})                  |  0.053  |
# |                frozenset({' Dog Food', ' Laundry Detergent '})                |  0.053  |
# |                   frozenset({'Dog Food ', ' Trash Bags '})                    |  0.056  |
# |                      frozenset({' Razors', 'Dog Food '})                      |  0.054  |
# |                frozenset({' Toilet Paper ', ' Paper Towels '})                |  0.054  |
# |                    frozenset({' Milk ', ' Paper Towels '})                    |  0.054  |
# |                    frozenset({'Milk ', ' Paper Towels '})                     |  0.054  |
# |                   frozenset({' Razors', ' Paper Towels '})                    |  0.054  |
# |           frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})           |  0.054  |
# |           frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})            |  0.054  |
# |          frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})           |  0.054  |
# |               frozenset({'Milk ', ' Milk ', ' Paper Towels '})                |  0.054  |
# |              frozenset({' Razors', ' Milk ', ' Paper Towels '})               |  0.054  |
# |               frozenset({' Razors', 'Milk ', ' Paper Towels '})               |  0.054  |
# |      frozenset({'Milk ', ' Toilet Paper ', ' Milk ', ' Paper Towels '})       |  0.054  |
# |     frozenset({' Razors', ' Milk ', ' Toilet Paper ', ' Paper Towels '})      |  0.054  |
# |      frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Paper Towels '})      |  0.054  |
# |          frozenset({' Razors', 'Milk ', ' Milk ', ' Paper Towels '})          |  0.054  |
# | frozenset({'Milk ', ' Paper Towels ', ' Razors', ' Milk ', ' Toilet Paper '}) |  0.054  |
# |                       frozenset({' Milk', ' Lotion '})                        |  0.051  |
# |                      frozenset({'Lotion ', ' Lotion '})                       |  0.051  |
# |                        frozenset({' Milk', 'Lotion '})                        |  0.051  |
# |                  frozenset({' Milk', 'Lotion ', ' Lotion '})                  |  0.051  |
# |                     frozenset({' Dog Food', ' Razors '})                      |  0.053  |
# +-------------------------------------------------------------------------------+---------+
#
# Derived Association Rules:
#
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |                             Antecedents                              |                           Consequents                            | Support |     Confidence     |
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |                        frozenset({'Razors'})                         |                      frozenset({' Razors'})                      |  0.05   |        1.0         |
# |                         frozenset({'Milk '})                         |                      frozenset({' Milk '})                       |  0.121  | 0.6612021857923497 |
# |                        frozenset({' Milk '})                         |                       frozenset({'Milk '})                       |  0.121  | 0.6994219653179191 |
# |                        frozenset({' Razors'})                        |                      frozenset({' Milk '})                       |  0.106  | 0.5047619047619047 |
# |                        frozenset({' Milk '})                         |                      frozenset({' Razors'})                      |  0.106  | 0.6127167630057804 |
# |                   frozenset({' Razors', 'Milk '})                    |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |                       frozenset({'Milk '})                       |  0.054  | 0.5094339622641509 |
# |            frozenset({' Razors', ' Laundry Detergent '})             |                      frozenset({' Milk '})                       |  0.052  |        1.0         |
# |             frozenset({' Laundry Detergent ', ' Milk '})             |                      frozenset({' Razors'})                      |  0.052  |        1.0         |
# |                     frozenset({' Toilet Paper'})                     |                      frozenset({' Milk '})                       |  0.065  |        1.0         |
# |                     frozenset({' Toilet Paper'})                     |                       frozenset({'Milk '})                       |  0.065  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper'})                 |                      frozenset({' Milk '})                       |  0.065  |        1.0         |
# |                    frozenset({'Milk ', ' Milk '})                    |                   frozenset({' Toilet Paper'})                   |  0.065  | 0.5371900826446281 |
# |                frozenset({' Toilet Paper', ' Milk '})                |                       frozenset({'Milk '})                       |  0.065  |        1.0         |
# |                     frozenset({' Toilet Paper'})                     |                  frozenset({'Milk ', ' Milk '})                  |  0.065  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper '})                |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |                  frozenset({' Toilet Paper '})                   |  0.054  | 0.5094339622641509 |
# |               frozenset({' Razors', ' Toilet Paper '})               |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                   frozenset({' Razors', 'Milk '})                    |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Toilet Paper '})               |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |          frozenset({' Razors', 'Milk ', ' Toilet Paper '})           |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |              frozenset({' Razors', 'Milk ', ' Milk '})               |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |          frozenset({' Razors', ' Milk ', ' Toilet Paper '})          |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |           frozenset({'Milk ', ' Toilet Paper ', ' Milk '})           |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                   frozenset({' Razors', 'Milk '})                    |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Toilet Paper '})               |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  | 0.5094339622641509 |
# |                frozenset({'Milk ', ' Toilet Paper '})                |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# |                    frozenset({' Toilet Paper '})                     |                    frozenset({' Trash Bags'})                    |  0.059  | 0.5221238938053097 |
# |                      frozenset({' Trash Bags'})                      |                  frozenset({' Toilet Paper '})                   |  0.059  | 0.5412844036697247 |
# |                     frozenset({' Trash Bags '})                      |                      frozenset({' Lotion'})                      |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |                   frozenset({' Trash Bags '})                    |  0.058  | 0.5420560747663552 |
# |                        frozenset({' Lotion'})                        |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5420560747663552 |
# |          frozenset({' Laundry Detergent ', ' Trash Bags '})          |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# |            frozenset({' Laundry Detergent ', ' Lotion'})             |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# |                frozenset({' Trash Bags ', ' Lotion'})                |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# |                     frozenset({' Trash Bags '})                      |          frozenset({' Laundry Detergent ', ' Lotion'})           |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |        frozenset({' Laundry Detergent ', ' Trash Bags '})        |  0.058  | 0.5420560747663552 |
# |                     frozenset({' Trash Bags '})                      |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5087719298245614 |
# |                      frozenset({' Dog Food '})                       |                      frozenset({' Lotion'})                      |  0.058  | 0.9830508474576273 |
# |                        frozenset({' Lotion'})                        |                    frozenset({' Dog Food '})                     |  0.058  | 0.5420560747663552 |
# |                      frozenset({' Dog Food '})                       |                   frozenset({' Trash Bags '})                    |  0.058  | 0.9830508474576273 |
# |                     frozenset({' Trash Bags '})                      |                    frozenset({' Dog Food '})                     |  0.058  | 0.5087719298245614 |
# |                      frozenset({' Dog Food '})                       |                frozenset({' Laundry Detergent '})                |  0.058  | 0.9830508474576273 |
# |              frozenset({' Dog Food ', ' Trash Bags '})               |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# |                 frozenset({' Dog Food ', ' Lotion'})                 |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# |                frozenset({' Trash Bags ', ' Lotion'})                |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# |                      frozenset({' Dog Food '})                       |              frozenset({' Trash Bags ', ' Lotion'})              |  0.058  | 0.9830508474576273 |
# |                     frozenset({' Trash Bags '})                      |               frozenset({' Dog Food ', ' Lotion'})               |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        |            frozenset({' Dog Food ', ' Trash Bags '})             |  0.058  | 0.5420560747663552 |
# |           frozenset({' Laundry Detergent ', ' Dog Food '})           |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# |            frozenset({' Laundry Detergent ', ' Lotion'})             |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# |                 frozenset({' Dog Food ', ' Lotion'})                 |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# |                      frozenset({' Dog Food '})                       |          frozenset({' Laundry Detergent ', ' Lotion'})           |  0.058  | 0.9830508474576273 |
# |                        frozenset({' Lotion'})                        |         frozenset({' Laundry Detergent ', ' Dog Food '})         |  0.058  | 0.5420560747663552 |
# |           frozenset({' Laundry Detergent ', ' Dog Food '})           |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# |          frozenset({' Laundry Detergent ', ' Trash Bags '})          |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# |              frozenset({' Dog Food ', ' Trash Bags '})               |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# |                      frozenset({' Dog Food '})                       |        frozenset({' Laundry Detergent ', ' Trash Bags '})        |  0.058  | 0.9830508474576273 |
# |                     frozenset({' Trash Bags '})                      |         frozenset({' Laundry Detergent ', ' Dog Food '})         |  0.058  | 0.5087719298245614 |
# |   frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags '})   |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# |     frozenset({' Laundry Detergent ', ' Dog Food ', ' Lotion'})      |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# |    frozenset({' Laundry Detergent ', ' Trash Bags ', ' Lotion'})     |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# |         frozenset({' Dog Food ', ' Trash Bags ', ' Lotion'})         |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# |           frozenset({' Laundry Detergent ', ' Dog Food '})           |              frozenset({' Trash Bags ', ' Lotion'})              |  0.058  |        1.0         |
# |          frozenset({' Laundry Detergent ', ' Trash Bags '})          |               frozenset({' Dog Food ', ' Lotion'})               |  0.058  |        1.0         |
# |            frozenset({' Laundry Detergent ', ' Lotion'})             |            frozenset({' Dog Food ', ' Trash Bags '})             |  0.058  |        1.0         |
# |              frozenset({' Dog Food ', ' Trash Bags '})               |          frozenset({' Laundry Detergent ', ' Lotion'})           |  0.058  |        1.0         |
# |                 frozenset({' Dog Food ', ' Lotion'})                 |        frozenset({' Laundry Detergent ', ' Trash Bags '})        |  0.058  |        1.0         |
# |                frozenset({' Trash Bags ', ' Lotion'})                |         frozenset({' Laundry Detergent ', ' Dog Food '})         |  0.058  |        1.0         |
# |                      frozenset({' Dog Food '})                       |  frozenset({' Laundry Detergent ', ' Trash Bags ', ' Lotion'})   |  0.058  | 0.9830508474576273 |
# |                     frozenset({' Trash Bags '})                      |   frozenset({' Laundry Detergent ', ' Dog Food ', ' Lotion'})    |  0.058  | 0.5087719298245614 |
# |                        frozenset({' Lotion'})                        | frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags '}) |  0.058  | 0.5420560747663552 |
# |                         frozenset({' Milk'})                         |                       frozenset({'Milk'})                        |  0.059  | 0.5363636363636364 |
# |                         frozenset({'Milk'})                          |                       frozenset({' Milk'})                       |  0.059  |        1.0         |
# |                  frozenset({'Laundry Detergent '})                   |                frozenset({' Laundry Detergent '})                |  0.104  |        1.0         |
# |           frozenset({'Laundry Detergent ', ' Trash Bags'})           |                frozenset({' Laundry Detergent '})                |  0.05   |        1.0         |
# |          frozenset({' Laundry Detergent ', ' Trash Bags'})           |                frozenset({'Laundry Detergent '})                 |  0.05   |        1.0         |
# |                     frozenset({' Paper Towels'})                     |                       frozenset({'Milk '})                       |  0.064  | 0.547008547008547  |
# |                     frozenset({'Paper Towels'})                      |                   frozenset({' Paper Towels'})                   |  0.053  |        1.0         |
# |                       frozenset({'Dog Food '})                       |                   frozenset({' Trash Bags '})                    |  0.056  | 0.5090909090909091 |
# |                    frozenset({' Paper Towels '})                     |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper '})                |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Toilet Paper '})               |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Paper Towels '})               |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |                  frozenset({' Paper Towels '})                   |  0.054  | 0.5094339622641509 |
# |               frozenset({' Razors', ' Paper Towels '})               |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# |                   frozenset({' Razors', 'Milk '})                    |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Paper Towels '})               |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# |           frozenset({'Milk ', ' Toilet Paper ', ' Milk '})           |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |       frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})       |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |           frozenset({'Milk ', ' Milk ', ' Paper Towels '})           |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |      frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})       |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper '})                |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |         frozenset({'Milk ', ' Toilet Paper ', ' Milk '})         |  0.054  |        1.0         |
# |          frozenset({' Razors', ' Milk ', ' Toilet Paper '})          |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |          frozenset({' Razors', ' Milk ', ' Paper Towels '})          |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |      frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})      |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |      frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})       |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |         frozenset({' Toilet Paper ', ' Paper Towels '})          |  0.054  | 0.5094339622641509 |
# |               frozenset({' Razors', ' Toilet Paper '})               |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Paper Towels '})               |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |             frozenset({' Razors', ' Paper Towels '})             |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |        frozenset({' Razors', ' Milk ', ' Toilet Paper '})        |  0.054  |        1.0         |
# |          frozenset({' Razors', 'Milk ', ' Toilet Paper '})           |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |          frozenset({' Razors', 'Milk ', ' Paper Towels '})           |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# |      frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})      |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |       frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})       |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                   frozenset({' Razors', 'Milk '})                    |         frozenset({' Toilet Paper ', ' Paper Towels '})          |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Toilet Paper '})               |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Paper Towels '})               |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper '})                |             frozenset({' Razors', ' Paper Towels '})             |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |        frozenset({' Razors', 'Milk ', ' Toilet Paper '})         |  0.054  |        1.0         |
# |              frozenset({' Razors', 'Milk ', ' Milk '})               |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# |          frozenset({' Razors', 'Milk ', ' Paper Towels '})           |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |          frozenset({' Razors', ' Milk ', ' Paper Towels '})          |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |           frozenset({'Milk ', ' Milk ', ' Paper Towels '})           |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |                   frozenset({' Razors', 'Milk '})                    |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  | 0.5094339622641509 |
# |               frozenset({' Razors', ' Paper Towels '})               |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |            frozenset({' Razors', 'Milk ', ' Milk '})             |  0.054  |        1.0         |
# |     frozenset({' Razors', 'Milk ', ' Milk ', ' Paper Towels '})      |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Paper Towels '})  |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |  frozenset({'Milk ', ' Toilet Paper ', ' Milk ', ' Paper Towels '})  |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# |     frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Milk '})      |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | frozenset({' Razors', ' Milk ', ' Toilet Paper ', ' Paper Towels '}) |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# |          frozenset({' Razors', 'Milk ', ' Paper Towels '})           |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |           frozenset({'Milk ', ' Milk ', ' Paper Towels '})           |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# |       frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})       |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# |              frozenset({' Razors', 'Milk ', ' Milk '})               |         frozenset({' Toilet Paper ', ' Paper Towels '})          |  0.054  |        1.0         |
# |          frozenset({' Razors', 'Milk ', ' Toilet Paper '})           |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |           frozenset({'Milk ', ' Toilet Paper ', ' Milk '})           |             frozenset({' Razors', ' Paper Towels '})             |  0.054  |        1.0         |
# |          frozenset({' Razors', ' Milk ', ' Paper Towels '})          |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# |      frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})      |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# |      frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})       |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# |          frozenset({' Razors', ' Milk ', ' Toilet Paper '})          |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Paper Towels '})                |        frozenset({' Razors', ' Milk ', ' Toilet Paper '})        |  0.054  |        1.0         |
# |                   frozenset({' Razors', 'Milk '})                    |    frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})     |  0.054  |        1.0         |
# |                frozenset({'Milk ', ' Toilet Paper '})                |        frozenset({' Razors', ' Milk ', ' Paper Towels '})        |  0.054  |        1.0         |
# |               frozenset({' Razors', ' Paper Towels '})               |         frozenset({'Milk ', ' Toilet Paper ', ' Milk '})         |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Paper Towels '})                |        frozenset({' Razors', 'Milk ', ' Toilet Paper '})         |  0.054  |        1.0         |
# |           frozenset({' Toilet Paper ', ' Paper Towels '})            |            frozenset({' Razors', 'Milk ', ' Milk '})             |  0.054  |        1.0         |
# |                   frozenset({' Razors', ' Milk '})                   |     frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})     |  0.054  | 0.5094339622641509 |
# |               frozenset({' Razors', ' Toilet Paper '})               |         frozenset({'Milk ', ' Milk ', ' Paper Towels '})         |  0.054  |        1.0         |
# |               frozenset({' Milk ', ' Toilet Paper '})                |        frozenset({' Razors', 'Milk ', ' Paper Towels '})         |  0.054  |        1.0         |
# |                    frozenset({' Paper Towels '})                     |   frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Milk '})    |  0.054  |        1.0         |
# |                       frozenset({' Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                     frozenset({' Lotion '})                      |  0.051  |        1.0         |
# |                       frozenset({' Lotion '})                        |                      frozenset({'Lotion '})                      |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                   frozenset({' Milk', 'Lotion '})                    |                     frozenset({' Lotion '})                      |  0.051  |        1.0         |
# |                   frozenset({' Milk', ' Lotion '})                   |                      frozenset({'Lotion '})                      |  0.051  |        1.0         |
# |                  frozenset({'Lotion ', ' Lotion '})                  |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# |                        frozenset({'Lotion '})                        |                 frozenset({' Milk', ' Lotion '})                 |  0.051  |        1.0         |
# |                       frozenset({' Lotion '})                        |                 frozenset({' Milk', 'Lotion '})                  |  0.051  |        1.0         |
# |                       frozenset({' Razors '})                        |                     frozenset({' Dog Food'})                     |  0.053  |        1.0         |
# +----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
#
#
#
# Frequent Itemsets from amazon_data.csv:
#
# +------------------------------------------------------+---------+
# |                       Itemsets                       | Support |
# +------------------------------------------------------+---------+
# |                frozenset({'Cheese'})                 |  0.484  |
# |                 frozenset({'Flour'})                 |  0.198  |
# |                frozenset({'Diapers'})                |  0.181  |
# |                 frozenset({'Juice'})                 |  0.124  |
# |               frozenset({'Detergent'})               |  0.262  |
# |                 frozenset({'Sugar'})                 |  0.184  |
# |                  frozenset({'Tea'})                  |  0.272  |
# |                frozenset({'Shampoo'})                |  0.151  |
# |            frozenset({'Cheese', 'Flour'})            |  0.127  |
# |           frozenset({'Diapers', 'Cheese'})           |  0.118  |
# |           frozenset({'Diapers', 'Flour'})            |  0.06   |
# |           frozenset({'Diapers', 'Sugar'})            |  0.058  |
# |      frozenset({'Diapers', 'Cheese', 'Flour'})       |  0.06   |
# |      frozenset({'Diapers', 'Cheese', 'Sugar'})       |  0.058  |
# |            frozenset({'Flour', 'Juice'})             |  0.071  |
# |             frozenset({'Tea', 'Juice'})              |  0.053  |
# |          frozenset({'Cheese', 'Detergent'})          |  0.115  |
# |           frozenset({'Detergent', 'Tea'})            |   0.1   |
# |      frozenset({'Cheese', 'Tea', 'Detergent'})       |  0.052  |
# |            frozenset({'Cheese', 'Sugar'})            |  0.121  |
# |          frozenset({'Detergent', 'Sugar'})           |  0.063  |
# |     frozenset({'Cheese', 'Sugar', 'Detergent'})      |  0.063  |
# |             frozenset({'Cheese', 'Tea'})             |  0.052  |
# |         frozenset({'Detergent', 'Shampoo'})          |  0.151  |
# |            frozenset({'Shampoo', 'Tea'})             |  0.052  |
# |           frozenset({'Cheese', 'Shampoo'})           |  0.052  |
# |      frozenset({'Detergent', 'Shampoo', 'Tea'})      |  0.052  |
# |    frozenset({'Cheese', 'Shampoo', 'Detergent'})     |  0.052  |
# |       frozenset({'Cheese', 'Shampoo', 'Tea'})        |  0.052  |
# | frozenset({'Cheese', 'Shampoo', 'Tea', 'Detergent'}) |  0.052  |
# +------------------------------------------------------+---------+
#
# Derived Association Rules:
#
# +-----------------------------------------------+-------------------------------------+---------+--------------------+
# |                  Antecedents                  |             Consequents             | Support |     Confidence     |
# +-----------------------------------------------+-------------------------------------+---------+--------------------+
# |             frozenset({'Flour'})              |        frozenset({'Cheese'})        |  0.127  | 0.6414141414141414 |
# |            frozenset({'Diapers'})             |        frozenset({'Cheese'})        |  0.118  | 0.6519337016574586 |
# |       frozenset({'Diapers', 'Cheese'})        |        frozenset({'Flour'})         |  0.06   | 0.5084745762711864 |
# |        frozenset({'Diapers', 'Flour'})        |        frozenset({'Cheese'})        |  0.06   |        1.0         |
# |        frozenset({'Diapers', 'Sugar'})        |        frozenset({'Cheese'})        |  0.058  |        1.0         |
# |             frozenset({'Juice'})              |        frozenset({'Flour'})         |  0.071  | 0.5725806451612903 |
# |         frozenset({'Cheese', 'Tea'})          |      frozenset({'Detergent'})       |  0.052  |        1.0         |
# |        frozenset({'Detergent', 'Tea'})        |        frozenset({'Cheese'})        |  0.052  | 0.5199999999999999 |
# |             frozenset({'Sugar'})              |        frozenset({'Cheese'})        |  0.121  | 0.657608695652174  |
# |        frozenset({'Cheese', 'Sugar'})         |      frozenset({'Detergent'})       |  0.063  | 0.5206611570247934 |
# |      frozenset({'Cheese', 'Detergent'})       |        frozenset({'Sugar'})         |  0.063  | 0.5478260869565217 |
# |       frozenset({'Detergent', 'Sugar'})       |        frozenset({'Cheese'})        |  0.063  |        1.0         |
# |           frozenset({'Detergent'})            |       frozenset({'Shampoo'})        |  0.151  | 0.5763358778625953 |
# |            frozenset({'Shampoo'})             |      frozenset({'Detergent'})       |  0.151  |        1.0         |
# |        frozenset({'Detergent', 'Tea'})        |       frozenset({'Shampoo'})        |  0.052  | 0.5199999999999999 |
# |         frozenset({'Shampoo', 'Tea'})         |      frozenset({'Detergent'})       |  0.052  |        1.0         |
# |       frozenset({'Cheese', 'Shampoo'})        |      frozenset({'Detergent'})       |  0.052  |        1.0         |
# |       frozenset({'Cheese', 'Shampoo'})        |         frozenset({'Tea'})          |  0.052  |        1.0         |
# |         frozenset({'Cheese', 'Tea'})          |       frozenset({'Shampoo'})        |  0.052  |        1.0         |
# |         frozenset({'Shampoo', 'Tea'})         |        frozenset({'Cheese'})        |  0.052  |        1.0         |
# |    frozenset({'Cheese', 'Shampoo', 'Tea'})    |      frozenset({'Detergent'})       |  0.052  |        1.0         |
# | frozenset({'Cheese', 'Shampoo', 'Detergent'}) |         frozenset({'Tea'})          |  0.052  |        1.0         |
# |   frozenset({'Cheese', 'Tea', 'Detergent'})   |       frozenset({'Shampoo'})        |  0.052  |        1.0         |
# |  frozenset({'Detergent', 'Shampoo', 'Tea'})   |        frozenset({'Cheese'})        |  0.052  |        1.0         |
# |       frozenset({'Cheese', 'Shampoo'})        |   frozenset({'Detergent', 'Tea'})   |  0.052  |        1.0         |
# |         frozenset({'Cheese', 'Tea'})          | frozenset({'Detergent', 'Shampoo'}) |  0.052  |        1.0         |
# |         frozenset({'Shampoo', 'Tea'})         | frozenset({'Cheese', 'Detergent'})  |  0.052  |        1.0         |
# |        frozenset({'Detergent', 'Tea'})        |  frozenset({'Cheese', 'Shampoo'})   |  0.052  | 0.5199999999999999 |
# +-----------------------------------------------+-------------------------------------+---------+--------------------+
#
#
#
# Frequent Itemsets from best_buy_data.csv:
#
# +----------------------------------------------------------------+---------+
# |                            Itemsets                            | Support |
# +----------------------------------------------------------------+---------+
# |                    frozenset({'Keyboard '})                    |  0.12   |
# |                   frozenset({' Keyboard '})                    |  0.055  |
# |                   frozenset({' Smartwatch'})                   |  0.127  |
# |                   frozenset({'Smartwatch'})                    |  0.058  |
# |               frozenset({'External Hard Drive'})               |  0.051  |
# |              frozenset({' External Hard Drive'})               |  0.051  |
# ...
# |                      frozenset({' Toothpaste ', ' Insect Repellent '})                      |                   frozenset({' Band-Aids ', ' First Aid Supplies'})                    |  0.079  |        1.0         |
# |                             frozenset({' First Aid Supplies'})                              |            frozenset({' Band-Aids ', ' Toothpaste ', ' Insect Repellent '})            |  0.079  | 0.5448275862068966 |
# |                                 frozenset({' Band-Aids '})                                  |        frozenset({' First Aid Supplies', ' Toothpaste ', ' Insect Repellent '})        |  0.079  | 0.5563380281690141 |
# |                                 frozenset({' Toothpaste '})                                 |        frozenset({' Band-Aids ', ' First Aid Supplies', ' Insect Repellent '})         |  0.079  | 0.5602836879432624 |
# |                                 frozenset({'Toothpaste '})                                  |                              frozenset({' Toothpaste '})                               |  0.062  |        1.0         |
# |                                  frozenset({' Band-Aids'})                                  |                               frozenset({'Toothpaste '})                               |  0.062  |        1.0         |
# |                                 frozenset({'Toothpaste '})                                  |                               frozenset({' Band-Aids'})                                |  0.062  |        1.0         |
# |                                  frozenset({' Band-Aids'})                                  |                              frozenset({' Toothpaste '})                               |  0.062  |        1.0         |
# |                          frozenset({' Band-Aids', ' Toothpaste '})                          |                               frozenset({'Toothpaste '})                               |  0.062  |        1.0         |
# |                          frozenset({' Band-Aids', 'Toothpaste '})                           |                              frozenset({' Toothpaste '})                               |  0.062  |        1.0         |
# |                         frozenset({' Toothpaste ', 'Toothpaste '})                          |                               frozenset({' Band-Aids'})                                |  0.062  |        1.0         |
# |                                  frozenset({' Band-Aids'})                                  |                       frozenset({' Toothpaste ', 'Toothpaste '})                       |  0.062  |        1.0         |
# |                                 frozenset({'Toothpaste '})                                  |                       frozenset({' Band-Aids', ' Toothpaste '})                        |  0.062  |        1.0         |
# |                           frozenset({' Blood Pressure Monitor '})                           |                         frozenset({'Blood Pressure Monitor '})                         |  0.063  | 0.5338983050847458 |
# |                           frozenset({'Blood Pressure Monitor '})                            |                        frozenset({' Blood Pressure Monitor '})                         |  0.063  |       0.504        |
# |                   frozenset({' Thermometer', ' Blood Pressure Monitor '})                   |                         frozenset({'Blood Pressure Monitor '})                         |  0.058  |        1.0         |
# |                   frozenset({' Thermometer', 'Blood Pressure Monitor '})                    |                        frozenset({' Blood Pressure Monitor '})                         |  0.058  |        1.0         |
# |             frozenset({' Blood Pressure Monitor ', 'Blood Pressure Monitor '})              |                              frozenset({' Thermometer'})                               |  0.058  | 0.9206349206349207 |
# |                             frozenset({' First Aid Supplies'})                              |                               frozenset({' Band-Aids '})                               |  0.079  | 0.5448275862068966 |
# |                                 frozenset({' Band-Aids '})                                  |                           frozenset({' First Aid Supplies'})                           |  0.079  | 0.5563380281690141 |
# |                                 frozenset({' Band-Aids '})                                  |                           frozenset({' Insect Repellent '})                            |  0.079  | 0.5563380281690141 |
# |                      frozenset({' Band-Aids ', ' First Aid Supplies'})                      |                           frozenset({' Insect Repellent '})                            |  0.079  |        1.0         |
# |                  frozenset({' First Aid Supplies', ' Insect Repellent '})                   |                               frozenset({' Band-Aids '})                               |  0.079  |        1.0         |
# |                      frozenset({' Band-Aids ', ' Insect Repellent '})                       |                           frozenset({' First Aid Supplies'})                           |  0.079  |        1.0         |
# |                             frozenset({' First Aid Supplies'})                              |                    frozenset({' Band-Aids ', ' Insect Repellent '})                    |  0.079  | 0.5448275862068966 |
# |                                 frozenset({' Band-Aids '})                                  |                frozenset({' First Aid Supplies', ' Insect Repellent '})                |  0.079  | 0.5563380281690141 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |                           frozenset({' Insect Repellent '})                            |  0.073  |        1.0         |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            |                         frozenset({' Blood Pressure Monitor'})                         |  0.136  | 0.9855072463768115 |
# |                           frozenset({' Blood Pressure Monitor'})                            |                         frozenset({' Cold and Flu Medicine '})                         |  0.136  | 0.7272727272727273 |
# |                           frozenset({' Cold and Flu Medicine '})                            |                         frozenset({'Cold and Flu Medicine '})                          |  0.075  | 0.5434782608695652 |
# |                           frozenset({' Cold and Flu Medicine '})                            |                           frozenset({' Insect Repellent '})                            |  0.073  | 0.5289855072463767 |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  | 0.9733333333333333 |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  | 0.5367647058823529 |
# |                           frozenset({' Cold and Flu Medicine '})                            |            frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.073  | 0.5289855072463767 |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |                           frozenset({' Insect Repellent '})                            |  0.073  | 0.9733333333333333 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            |              frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})               |  0.073  | 0.5289855072463767 |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |                           frozenset({' Insect Repellent '})                            |  0.073  | 0.5367647058823529 |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            |              frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})              |  0.073  | 0.5289855072463767 |
# |   frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine ', ' Insect Repellent '})    |                         frozenset({' Blood Pressure Monitor'})                         |  0.073  |        1.0         |
# | frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine ', ' Blood Pressure Monitor'}) |                           frozenset({' Insect Repellent '})                            |  0.073  |        1.0         |
# |   frozenset({'Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'})    |                         frozenset({' Cold and Flu Medicine '})                         |  0.073  |        1.0         |
# |   frozenset({' Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'})   |                         frozenset({'Cold and Flu Medicine '})                          |  0.073  |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})               |              frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})              |  0.073  | 0.9733333333333333 |
# |                 frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})                 |           frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.073  |        1.0         |
# |              frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})               |              frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})              |  0.073  |        1.0         |
# |                frozenset({' Cold and Flu Medicine ', ' Insect Repellent '})                 |            frozenset({'Cold and Flu Medicine ', ' Blood Pressure Monitor'})            |  0.073  |        1.0         |
# |              frozenset({' Cold and Flu Medicine ', ' Blood Pressure Monitor'})              |              frozenset({'Cold and Flu Medicine ', ' Insect Repellent '})               |  0.073  | 0.5367647058823529 |
# |                frozenset({' Insect Repellent ', ' Blood Pressure Monitor'})                 |            frozenset({'Cold and Flu Medicine ', ' Cold and Flu Medicine '})            |  0.073  |        1.0         |
# |                           frozenset({' Cold and Flu Medicine '})                            | frozenset({'Cold and Flu Medicine ', ' Insect Repellent ', ' Blood Pressure Monitor'}) |  0.073  | 0.5289855072463767 |
# |                    frozenset({' Band-Aids ', ' Cold and Flu Medicine '})                    |                         frozenset({' Blood Pressure Monitor'})                         |  0.063  |        1.0         |
# |                    frozenset({' Band-Aids ', ' Blood Pressure Monitor'})                    |                         frozenset({' Cold and Flu Medicine '})                         |  0.063  |        1.0         |
# |                                 frozenset({' Eye Drops '})                                  |                               frozenset({'Eye Drops '})                                |  0.104  | 0.6499999999999999 |
# |                                  frozenset({'Eye Drops '})                                  |                               frozenset({' Eye Drops '})                               |  0.104  |        1.0         |
# |                                  frozenset({'Eye Drops '})                                  |                        frozenset({' Blood Pressure Monitor '})                         |  0.055  | 0.5288461538461539 |
# |                   frozenset({' Eye Drops ', ' Blood Pressure Monitor '})                    |                               frozenset({'Eye Drops '})                                |  0.055  |        1.0         |
# |                          frozenset({' Eye Drops ', 'Eye Drops '})                           |                        frozenset({' Blood Pressure Monitor '})                         |  0.055  | 0.5288461538461539 |
# |                    frozenset({' Blood Pressure Monitor ', 'Eye Drops '})                    |                               frozenset({' Eye Drops '})                               |  0.055  |        1.0         |
# |                                  frozenset({'Eye Drops '})                                  |                 frozenset({' Eye Drops ', ' Blood Pressure Monitor '})                 |  0.055  | 0.5288461538461539 |
# |                             frozenset({'First Aid Supplies '})                              |                              frozenset({' Thermometer'})                               |  0.056  |        1.0         |
# |                                frozenset({' Thermometer '})                                 |                               frozenset({' Eye Drops '})                               |  0.056  |        1.0         |
# |                              frozenset({'Insect Repellent '})                               |                          frozenset({' First Aid Supplies '})                           |  0.05   |        1.0         |
# |                              frozenset({'Insect Repellent '})                               |                              frozenset({' Thermometer'})                               |  0.05   |        1.0         |
# |                     frozenset({' Thermometer', ' First Aid Supplies '})                     |                            frozenset({'Insect Repellent '})                            |  0.05   | 0.9803921568627452 |
# |                      frozenset({' Thermometer', 'Insect Repellent '})                       |                          frozenset({' First Aid Supplies '})                           |  0.05   |        1.0         |
# |                  frozenset({' First Aid Supplies ', 'Insect Repellent '})                   |                              frozenset({' Thermometer'})                               |  0.05   |        1.0         |
# |                              frozenset({'Insect Repellent '})                               |                  frozenset({' Thermometer', ' First Aid Supplies '})                   |  0.05   |        1.0         |
# +---------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+---------+--------------------+

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
from tabulate import tabulate
import time

def get_txs(file):
    """Fetch transactions from CSV."""
    txs = pd.read_csv(file)['Filtered Transaction'].str.split(', ').tolist()
    return txs

def analyze_fp_growth(file, sup, conf):
    """Analyzes transactions using the FP-Growth method."""
    start_time = time.time()  # Start the timer

    txs = get_txs(file)
    
    # Encode transactions into a DataFrame
    enc = TransactionEncoder()
    tx_data = enc.fit(txs).transform(txs)
    df_tx = pd.DataFrame(tx_data, columns=enc.columns_)
    
    # Generate frequent itemsets using FP-Growth
    frequent_itemsets = fpgrowth(df_tx, min_support=sup, use_colnames=True)
    
    # Derive association rules from the frequent itemsets
    assoc_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=conf)
    
    # Display results in a structured table format
    print(f"\nFrequent Itemsets from {file.split('/')[-1]}:\n")
    if not frequent_itemsets.empty:
        itemsets_table = tabulate(
            frequent_itemsets[['itemsets', 'support']],
            headers=['Itemsets', 'Support'],
            tablefmt='pretty'
        )
        print(itemsets_table)
    else:
        print("No frequent itemsets found for the given parameters.")

    print("\nDerived Association Rules:\n")
    if not assoc_rules.empty:
        rules_table = tabulate(
            assoc_rules[['antecedents', 'consequents', 'support', 'confidence']],
            headers=['Antecedents', 'Consequents', 'Support', 'Confidence'],
            tablefmt='pretty'
        )
        print(rules_table)
    else:
        print("No association rules found for the given parameters.")

    end_time = time.time()  # End the timer
    print(f"\nExecution time for {file.split('/')[-1]}: {end_time - start_time:.2f} seconds\n")

def run():
    names = ['Walmart', 'Amazon', 'Best Buy', 'Costco', 'Walgreens']
    paths = {
        '1': '/Users/pradeepvarma/Downloads/dataset/walmart_data.csv',
        '2': '/Users/pradeepvarma/Downloads/dataset/amazon_data.csv',
        '3': '/Users/pradeepvarma/Downloads/dataset/best_buy_data.csv',
        '4': '/Users/pradeepvarma/Downloads/dataset/costco_data.csv',
        '5': '/Users/pradeepvarma/Downloads/dataset/walgreens_data.csv',
    }
    
    print("Choose dataset(s) to analyze:")
    for i, name in enumerate(names, start=1):
        print(f"{i} - {name}")
    choices = input("Enter dataset numbers (space-separated, e.g., 1 3): ").split()

    min_sup = float(input("\nMinimum support (e.g., 0.05): "))
    min_conf = float(input("Minimum confidence (e.g., 0.5): "))

    for choice in choices:
        if choice in paths:
            analyze_fp_growth(paths[choice], min_sup, min_conf)
        else:
            print(f"Invalid choice: {choice}")

if __name__ == "__main__":
    run()
# Out:
# Choose dataset(s) to analyze:
# 1 - Walmart
# 2 - Amazon
# 3 - Best Buy
# 4 - Costco
# 5 - Walgreens
# Enter dataset numbers (space-separated, e.g., 1 3): 1 3 4
#
# Minimum support (e.g., 0.05): 0.05
# Minimum confidence (e.g., 0.5): 0.5
#
# Frequent Itemsets from walmart_data.csv:
#
# +----+-------------------------------------------------------------------------------+---------+
# |    |                                   Itemsets                                    | Support |
# +----+-------------------------------------------------------------------------------+---------+
# | 0  |                            frozenset({' Razors'})                             |  0.21   |
# | 1  |                             frozenset({'Razors'})                             |  0.05   |
# | 2  |                             frozenset({'Milk '})                              |  0.183  |
# | 3  |                             frozenset({' Milk '})                             |  0.173  |
# | 4  |                         frozenset({' Toilet Paper'})                          |  0.065  |
# | 5  |                         frozenset({' Toilet Paper '})                         |  0.113  |
# | 6  |                          frozenset({' Trash Bags'})                           |  0.109  |
# | 7  |                            frozenset({' Lotion'})                             |  0.107  |
# | 8  |                      frozenset({' Laundry Detergent '})                       |  0.267  |
# | 9  |                          frozenset({' Trash Bags '})                          |  0.114  |
# | 10 |                           frozenset({' Dog Food '})                           |  0.059  |
# | 11 |                             frozenset({' Milk'})                              |  0.11   |
# | 12 |                              frozenset({'Milk'})                              |  0.059  |
# | 13 |                       frozenset({'Laundry Detergent '})                       |  0.104  |
# | 14 |                         frozenset({' Paper Towels'})                          |  0.117  |
# | 15 |                          frozenset({'Paper Towels'})                          |  0.053  |
# | 16 |                           frozenset({' Dog Food'})                            |  0.172  |
# | 17 |                           frozenset({'Dog Food '})                            |  0.11   |
# | 18 |                         frozenset({' Paper Towels '})                         |  0.054  |
# | 19 |                            frozenset({' Lotion '})                            |  0.051  |
# | 20 |                            frozenset({'Lotion '})                             |  0.051  |
# | 21 |                            frozenset({' Razors '})                            |  0.053  |
# | 22 |                 frozenset({' Razors', ' Laundry Detergent '})                 |  0.052  |
# | 23 |                       frozenset({' Razors', 'Razors'})                        |  0.05   |
# | 24 |                        frozenset({' Razors', 'Milk '})                        |  0.054  |
# | 25 |                        frozenset({'Milk ', ' Milk '})                         |  0.121  |
# | 26 |                       frozenset({' Razors', ' Milk '})                        |  0.106  |
# | 27 |                 frozenset({' Laundry Detergent ', ' Milk '})                  |  0.052  |
# | 28 |                   frozenset({' Razors', 'Milk ', ' Milk '})                   |  0.054  |
# | 29 |            frozenset({' Razors', ' Milk ', ' Laundry Detergent '})            |  0.052  |
# | 30 |                    frozenset({' Toilet Paper', ' Milk '})                     |  0.065  |
# | 31 |                     frozenset({'Milk ', ' Toilet Paper'})                     |  0.065  |
# | 32 |                frozenset({'Milk ', ' Toilet Paper', ' Milk '})                |  0.065  |
# | 33 |                    frozenset({' Milk ', ' Toilet Paper '})                    |  0.054  |
# | 34 |                    frozenset({'Milk ', ' Toilet Paper '})                     |  0.054  |
# | 35 |                   frozenset({' Razors', ' Toilet Paper '})                    |  0.054  |
# | 36 |               frozenset({'Milk ', ' Toilet Paper ', ' Milk '})                |  0.054  |
# | 37 |              frozenset({' Razors', ' Milk ', ' Toilet Paper '})               |  0.054  |
# | 38 |               frozenset({' Razors', 'Milk ', ' Toilet Paper '})               |  0.054  |
# | 39 |          frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Milk '})          |  0.054  |
# | 40 |                 frozenset({' Toilet Paper ', ' Trash Bags'})                  |  0.059  |
# | 41 |               frozenset({' Laundry Detergent ', ' Trash Bags'})               |  0.05   |
# | 42 |                    frozenset({' Trash Bags ', ' Lotion'})                     |  0.058  |
# | 43 |                 frozenset({' Laundry Detergent ', ' Lotion'})                 |  0.058  |
# | 44 |         frozenset({' Laundry Detergent ', ' Trash Bags ', ' Lotion'})         |  0.058  |
# | 45 |              frozenset({' Laundry Detergent ', ' Trash Bags '})               |  0.058  |
# | 46 |                     frozenset({' Dog Food ', ' Lotion'})                      |  0.058  |
# | 47 |                   frozenset({' Dog Food ', ' Trash Bags '})                   |  0.058  |
# | 48 |               frozenset({' Laundry Detergent ', ' Dog Food '})                |  0.058  |
# | 49 |             frozenset({' Dog Food ', ' Trash Bags ', ' Lotion'})              |  0.058  |
# | 50 |          frozenset({' Laundry Detergent ', ' Dog Food ', ' Lotion'})          |  0.058  |
# | 51 |       frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags '})        |  0.058  |
# | 52 |  frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags ', ' Lotion'})  |  0.058  |
# | 53 |                         frozenset({' Milk', 'Milk'})                          |  0.059  |
# | 54 |           frozenset({'Laundry Detergent ', ' Laundry Detergent '})            |  0.104  |
# | 55 |               frozenset({'Laundry Detergent ', ' Trash Bags'})                |  0.05   |
# | 56 |    frozenset({'Laundry Detergent ', ' Laundry Detergent ', ' Trash Bags'})    |  0.05   |
# | 57 |                     frozenset({'Milk ', ' Paper Towels'})                     |  0.064  |
# | 58 |                 frozenset({'Paper Towels', ' Paper Towels'})                  |  0.053  |
# | 59 |                frozenset({' Dog Food', ' Laundry Detergent '})                |  0.053  |
# | 60 |                   frozenset({'Dog Food ', ' Trash Bags '})                    |  0.056  |
# | 61 |                      frozenset({' Razors', 'Dog Food '})                      |  0.054  |
# | 62 |                frozenset({' Toilet Paper ', ' Paper Towels '})                |  0.054  |
# | 63 |                    frozenset({' Milk ', ' Paper Towels '})                    |  0.054  |
# | 64 |                    frozenset({'Milk ', ' Paper Towels '})                     |  0.054  |
# | 65 |                   frozenset({' Razors', ' Paper Towels '})                    |  0.054  |
# | 66 |           frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})           |  0.054  |
# | 67 |           frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})            |  0.054  |
# | 68 |          frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})           |  0.054  |
# | 69 |               frozenset({'Milk ', ' Milk ', ' Paper Towels '})                |  0.054  |
# | 70 |              frozenset({' Razors', ' Milk ', ' Paper Towels '})               |  0.054  |
# | 71 |               frozenset({' Razors', 'Milk ', ' Paper Towels '})               |  0.054  |
# | 72 |      frozenset({'Milk ', ' Toilet Paper ', ' Milk ', ' Paper Towels '})       |  0.054  |
# | 73 |     frozenset({' Razors', ' Milk ', ' Toilet Paper ', ' Paper Towels '})      |  0.054  |
# | 74 |      frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Paper Towels '})      |  0.054  |
# | 75 |          frozenset({' Razors', 'Milk ', ' Milk ', ' Paper Towels '})          |  0.054  |
# | 76 | frozenset({'Milk ', ' Paper Towels ', ' Razors', ' Milk ', ' Toilet Paper '}) |  0.054  |
# | 77 |                       frozenset({' Milk', ' Lotion '})                        |  0.051  |
# | 78 |                      frozenset({'Lotion ', ' Lotion '})                       |  0.051  |
# | 79 |                        frozenset({' Milk', 'Lotion '})                        |  0.051  |
# | 80 |                  frozenset({' Milk', 'Lotion ', ' Lotion '})                  |  0.051  |
# | 81 |                     frozenset({' Dog Food', ' Razors '})                      |  0.053  |
# +----+-------------------------------------------------------------------------------+---------+
#
# Derived Association Rules:
#
# +-----+----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |     |                             Antecedents                              |                           Consequents                            | Support |     Confidence     |
# +-----+----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
# |  0  |                        frozenset({'Razors'})                         |                      frozenset({' Razors'})                      |  0.05   |        1.0         |
# |  1  |                         frozenset({'Milk '})                         |                      frozenset({' Milk '})                       |  0.121  | 0.6612021857923497 |
# |  2  |                        frozenset({' Milk '})                         |                       frozenset({'Milk '})                       |  0.121  | 0.6994219653179191 |
# |  3  |                        frozenset({' Razors'})                        |                      frozenset({' Milk '})                       |  0.106  | 0.5047619047619047 |
# |  4  |                        frozenset({' Milk '})                         |                      frozenset({' Razors'})                      |  0.106  | 0.6127167630057804 |
# |  5  |                   frozenset({' Razors', 'Milk '})                    |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# |  6  |                   frozenset({' Razors', ' Milk '})                   |                       frozenset({'Milk '})                       |  0.054  | 0.5094339622641509 |
# |  7  |            frozenset({' Razors', ' Laundry Detergent '})             |                      frozenset({' Milk '})                       |  0.052  |        1.0         |
# |  8  |             frozenset({' Laundry Detergent ', ' Milk '})             |                      frozenset({' Razors'})                      |  0.052  |        1.0         |
# |  9  |                     frozenset({' Toilet Paper'})                     |                      frozenset({' Milk '})                       |  0.065  |        1.0         |
# | 10  |                     frozenset({' Toilet Paper'})                     |                       frozenset({'Milk '})                       |  0.065  |        1.0         |
# | 11  |                frozenset({'Milk ', ' Toilet Paper'})                 |                      frozenset({' Milk '})                       |  0.065  |        1.0         |
# | 12  |                    frozenset({'Milk ', ' Milk '})                    |                   frozenset({' Toilet Paper'})                   |  0.065  | 0.5371900826446281 |
# | 13  |                frozenset({' Toilet Paper', ' Milk '})                |                       frozenset({'Milk '})                       |  0.065  |        1.0         |
# | 14  |                     frozenset({' Toilet Paper'})                     |                  frozenset({'Milk ', ' Milk '})                  |  0.065  |        1.0         |
# | 15  |                frozenset({'Milk ', ' Toilet Paper '})                |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 16  |               frozenset({' Milk ', ' Toilet Paper '})                |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 17  |                   frozenset({' Razors', ' Milk '})                   |                  frozenset({' Toilet Paper '})                   |  0.054  | 0.5094339622641509 |
# | 18  |               frozenset({' Razors', ' Toilet Paper '})               |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 19  |               frozenset({' Milk ', ' Toilet Paper '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 20  |                   frozenset({' Razors', 'Milk '})                    |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 21  |               frozenset({' Razors', ' Toilet Paper '})               |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 22  |                frozenset({'Milk ', ' Toilet Paper '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 23  |          frozenset({' Razors', 'Milk ', ' Toilet Paper '})           |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 24  |              frozenset({' Razors', 'Milk ', ' Milk '})               |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 25  |          frozenset({' Razors', ' Milk ', ' Toilet Paper '})          |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 26  |           frozenset({'Milk ', ' Toilet Paper ', ' Milk '})           |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 27  |                   frozenset({' Razors', 'Milk '})                    |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 28  |               frozenset({' Razors', ' Toilet Paper '})               |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# | 29  |                   frozenset({' Razors', ' Milk '})                   |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  | 0.5094339622641509 |
# | 30  |                frozenset({'Milk ', ' Toilet Paper '})                |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# | 31  |               frozenset({' Milk ', ' Toilet Paper '})                |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# | 32  |                    frozenset({' Toilet Paper '})                     |                    frozenset({' Trash Bags'})                    |  0.059  | 0.5221238938053097 |
# | 33  |                      frozenset({' Trash Bags'})                      |                  frozenset({' Toilet Paper '})                   |  0.059  | 0.5412844036697247 |
# | 34  |                     frozenset({' Trash Bags '})                      |                      frozenset({' Lotion'})                      |  0.058  | 0.5087719298245614 |
# | 35  |                        frozenset({' Lotion'})                        |                   frozenset({' Trash Bags '})                    |  0.058  | 0.5420560747663552 |
# | 36  |                        frozenset({' Lotion'})                        |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5420560747663552 |
# | 37  |          frozenset({' Laundry Detergent ', ' Trash Bags '})          |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# | 38  |            frozenset({' Laundry Detergent ', ' Lotion'})             |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# | 39  |                frozenset({' Trash Bags ', ' Lotion'})                |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# | 40  |                     frozenset({' Trash Bags '})                      |          frozenset({' Laundry Detergent ', ' Lotion'})           |  0.058  | 0.5087719298245614 |
# | 41  |                        frozenset({' Lotion'})                        |        frozenset({' Laundry Detergent ', ' Trash Bags '})        |  0.058  | 0.5420560747663552 |
# | 42  |                     frozenset({' Trash Bags '})                      |                frozenset({' Laundry Detergent '})                |  0.058  | 0.5087719298245614 |
# | 43  |                      frozenset({' Dog Food '})                       |                      frozenset({' Lotion'})                      |  0.058  | 0.9830508474576273 |
# | 44  |                        frozenset({' Lotion'})                        |                    frozenset({' Dog Food '})                     |  0.058  | 0.5420560747663552 |
# | 45  |                      frozenset({' Dog Food '})                       |                   frozenset({' Trash Bags '})                    |  0.058  | 0.9830508474576273 |
# | 46  |                     frozenset({' Trash Bags '})                      |                    frozenset({' Dog Food '})                     |  0.058  | 0.5087719298245614 |
# | 47  |                      frozenset({' Dog Food '})                       |                frozenset({' Laundry Detergent '})                |  0.058  | 0.9830508474576273 |
# | 48  |              frozenset({' Dog Food ', ' Trash Bags '})               |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# | 49  |                 frozenset({' Dog Food ', ' Lotion'})                 |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# | 50  |                frozenset({' Trash Bags ', ' Lotion'})                |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# | 51  |                      frozenset({' Dog Food '})                       |              frozenset({' Trash Bags ', ' Lotion'})              |  0.058  | 0.9830508474576273 |
# | 52  |                     frozenset({' Trash Bags '})                      |               frozenset({' Dog Food ', ' Lotion'})               |  0.058  | 0.5087719298245614 |
# | 53  |                        frozenset({' Lotion'})                        |            frozenset({' Dog Food ', ' Trash Bags '})             |  0.058  | 0.5420560747663552 |
# | 54  |           frozenset({' Laundry Detergent ', ' Dog Food '})           |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# | 55  |            frozenset({' Laundry Detergent ', ' Lotion'})             |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# | 56  |                 frozenset({' Dog Food ', ' Lotion'})                 |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# | 57  |                      frozenset({' Dog Food '})                       |          frozenset({' Laundry Detergent ', ' Lotion'})           |  0.058  | 0.9830508474576273 |
# | 58  |                        frozenset({' Lotion'})                        |         frozenset({' Laundry Detergent ', ' Dog Food '})         |  0.058  | 0.5420560747663552 |
# | 59  |           frozenset({' Laundry Detergent ', ' Dog Food '})           |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# | 60  |          frozenset({' Laundry Detergent ', ' Trash Bags '})          |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# | 61  |              frozenset({' Dog Food ', ' Trash Bags '})               |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# | 62  |                      frozenset({' Dog Food '})                       |        frozenset({' Laundry Detergent ', ' Trash Bags '})        |  0.058  | 0.9830508474576273 |
# | 63  |                     frozenset({' Trash Bags '})                      |         frozenset({' Laundry Detergent ', ' Dog Food '})         |  0.058  | 0.5087719298245614 |
# | 64  |   frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags '})   |                      frozenset({' Lotion'})                      |  0.058  |        1.0         |
# | 65  |     frozenset({' Laundry Detergent ', ' Dog Food ', ' Lotion'})      |                   frozenset({' Trash Bags '})                    |  0.058  |        1.0         |
# | 66  |    frozenset({' Laundry Detergent ', ' Trash Bags ', ' Lotion'})     |                    frozenset({' Dog Food '})                     |  0.058  |        1.0         |
# | 67  |         frozenset({' Dog Food ', ' Trash Bags ', ' Lotion'})         |                frozenset({' Laundry Detergent '})                |  0.058  |        1.0         |
# | 68  |           frozenset({' Laundry Detergent ', ' Dog Food '})           |              frozenset({' Trash Bags ', ' Lotion'})              |  0.058  |        1.0         |
# | 69  |          frozenset({' Laundry Detergent ', ' Trash Bags '})          |               frozenset({' Dog Food ', ' Lotion'})               |  0.058  |        1.0         |
# | 70  |            frozenset({' Laundry Detergent ', ' Lotion'})             |            frozenset({' Dog Food ', ' Trash Bags '})             |  0.058  |        1.0         |
# | 71  |              frozenset({' Dog Food ', ' Trash Bags '})               |          frozenset({' Laundry Detergent ', ' Lotion'})           |  0.058  |        1.0         |
# | 72  |                 frozenset({' Dog Food ', ' Lotion'})                 |        frozenset({' Laundry Detergent ', ' Trash Bags '})        |  0.058  |        1.0         |
# | 73  |                frozenset({' Trash Bags ', ' Lotion'})                |         frozenset({' Laundry Detergent ', ' Dog Food '})         |  0.058  |        1.0         |
# | 74  |                      frozenset({' Dog Food '})                       |  frozenset({' Laundry Detergent ', ' Trash Bags ', ' Lotion'})   |  0.058  | 0.9830508474576273 |
# | 75  |                     frozenset({' Trash Bags '})                      |   frozenset({' Laundry Detergent ', ' Dog Food ', ' Lotion'})    |  0.058  | 0.5087719298245614 |
# | 76  |                        frozenset({' Lotion'})                        | frozenset({' Laundry Detergent ', ' Dog Food ', ' Trash Bags '}) |  0.058  | 0.5420560747663552 |
# | 77  |                         frozenset({' Milk'})                         |                       frozenset({'Milk'})                        |  0.059  | 0.5363636363636364 |
# | 78  |                         frozenset({'Milk'})                          |                       frozenset({' Milk'})                       |  0.059  |        1.0         |
# | 79  |                  frozenset({'Laundry Detergent '})                   |                frozenset({' Laundry Detergent '})                |  0.104  |        1.0         |
# | 80  |           frozenset({'Laundry Detergent ', ' Trash Bags'})           |                frozenset({' Laundry Detergent '})                |  0.05   |        1.0         |
# | 81  |          frozenset({' Laundry Detergent ', ' Trash Bags'})           |                frozenset({'Laundry Detergent '})                 |  0.05   |        1.0         |
# | 82  |                     frozenset({' Paper Towels'})                     |                       frozenset({'Milk '})                       |  0.064  | 0.547008547008547  |
# | 83  |                     frozenset({'Paper Towels'})                      |                   frozenset({' Paper Towels'})                   |  0.053  |        1.0         |
# | 84  |                       frozenset({'Dog Food '})                       |                   frozenset({' Trash Bags '})                    |  0.056  | 0.5090909090909091 |
# | 85  |                    frozenset({' Paper Towels '})                     |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 86  |                    frozenset({' Paper Towels '})                     |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 87  |                    frozenset({' Paper Towels '})                     |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 88  |                    frozenset({' Paper Towels '})                     |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 89  |               frozenset({' Milk ', ' Toilet Paper '})                |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 90  |               frozenset({' Milk ', ' Paper Towels '})                |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 91  |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 92  |                    frozenset({' Paper Towels '})                     |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 93  |                frozenset({'Milk ', ' Toilet Paper '})                |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 94  |                frozenset({'Milk ', ' Paper Towels '})                |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 95  |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 96  |                    frozenset({' Paper Towels '})                     |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 97  |               frozenset({' Razors', ' Toilet Paper '})               |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 98  |               frozenset({' Razors', ' Paper Towels '})               |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 99  |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 100 |                    frozenset({' Paper Towels '})                     |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# | 101 |                frozenset({'Milk ', ' Paper Towels '})                |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 102 |               frozenset({' Milk ', ' Paper Towels '})                |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 103 |                    frozenset({' Paper Towels '})                     |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# | 104 |                   frozenset({' Razors', ' Milk '})                   |                  frozenset({' Paper Towels '})                   |  0.054  | 0.5094339622641509 |
# | 105 |               frozenset({' Razors', ' Paper Towels '})               |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 106 |               frozenset({' Milk ', ' Paper Towels '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 107 |                    frozenset({' Paper Towels '})                     |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# | 108 |                   frozenset({' Razors', 'Milk '})                    |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 109 |               frozenset({' Razors', ' Paper Towels '})               |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 110 |                frozenset({'Milk ', ' Paper Towels '})                |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 111 |                    frozenset({' Paper Towels '})                     |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# | 112 |           frozenset({'Milk ', ' Toilet Paper ', ' Milk '})           |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 113 |       frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})       |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 114 |           frozenset({'Milk ', ' Milk ', ' Paper Towels '})           |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 115 |      frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})       |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 116 |                frozenset({'Milk ', ' Toilet Paper '})                |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 117 |                frozenset({'Milk ', ' Paper Towels '})                |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 118 |               frozenset({' Milk ', ' Toilet Paper '})                |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 119 |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# | 120 |               frozenset({' Milk ', ' Paper Towels '})                |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 121 |                    frozenset({' Paper Towels '})                     |         frozenset({'Milk ', ' Toilet Paper ', ' Milk '})         |  0.054  |        1.0         |
# | 122 |          frozenset({' Razors', ' Milk ', ' Toilet Paper '})          |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 123 |          frozenset({' Razors', ' Milk ', ' Paper Towels '})          |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 124 |      frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})      |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 125 |      frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})       |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 126 |                   frozenset({' Razors', ' Milk '})                   |         frozenset({' Toilet Paper ', ' Paper Towels '})          |  0.054  | 0.5094339622641509 |
# | 127 |               frozenset({' Razors', ' Toilet Paper '})               |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 128 |               frozenset({' Razors', ' Paper Towels '})               |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 129 |               frozenset({' Milk ', ' Toilet Paper '})                |             frozenset({' Razors', ' Paper Towels '})             |  0.054  |        1.0         |
# | 130 |               frozenset({' Milk ', ' Paper Towels '})                |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# | 131 |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# | 132 |                    frozenset({' Paper Towels '})                     |        frozenset({' Razors', ' Milk ', ' Toilet Paper '})        |  0.054  |        1.0         |
# | 133 |          frozenset({' Razors', 'Milk ', ' Toilet Paper '})           |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 134 |          frozenset({' Razors', 'Milk ', ' Paper Towels '})           |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 135 |      frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})      |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 136 |       frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})       |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 137 |                   frozenset({' Razors', 'Milk '})                    |         frozenset({' Toilet Paper ', ' Paper Towels '})          |  0.054  |        1.0         |
# | 138 |               frozenset({' Razors', ' Toilet Paper '})               |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 139 |               frozenset({' Razors', ' Paper Towels '})               |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 140 |                frozenset({'Milk ', ' Toilet Paper '})                |             frozenset({' Razors', ' Paper Towels '})             |  0.054  |        1.0         |
# | 141 |                frozenset({'Milk ', ' Paper Towels '})                |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# | 142 |           frozenset({' Toilet Paper ', ' Paper Towels '})            |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# | 143 |                    frozenset({' Paper Towels '})                     |        frozenset({' Razors', 'Milk ', ' Toilet Paper '})         |  0.054  |        1.0         |
# | 144 |              frozenset({' Razors', 'Milk ', ' Milk '})               |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 145 |          frozenset({' Razors', 'Milk ', ' Paper Towels '})           |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 146 |          frozenset({' Razors', ' Milk ', ' Paper Towels '})          |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 147 |           frozenset({'Milk ', ' Milk ', ' Paper Towels '})           |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 148 |                   frozenset({' Razors', 'Milk '})                    |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 149 |                   frozenset({' Razors', ' Milk '})                   |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  | 0.5094339622641509 |
# | 150 |               frozenset({' Razors', ' Paper Towels '})               |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# | 151 |                frozenset({'Milk ', ' Paper Towels '})                |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# | 152 |               frozenset({' Milk ', ' Paper Towels '})                |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# | 153 |                    frozenset({' Paper Towels '})                     |            frozenset({' Razors', 'Milk ', ' Milk '})             |  0.054  |        1.0         |
# | 154 |     frozenset({' Razors', 'Milk ', ' Milk ', ' Paper Towels '})      |                  frozenset({' Toilet Paper '})                   |  0.054  |        1.0         |
# | 155 | frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Paper Towels '})  |                      frozenset({' Milk '})                       |  0.054  |        1.0         |
# | 156 |  frozenset({'Milk ', ' Toilet Paper ', ' Milk ', ' Paper Towels '})  |                      frozenset({' Razors'})                      |  0.054  |        1.0         |
# | 157 |     frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Milk '})      |                  frozenset({' Paper Towels '})                   |  0.054  |        1.0         |
# | 158 | frozenset({' Razors', ' Milk ', ' Toilet Paper ', ' Paper Towels '}) |                       frozenset({'Milk '})                       |  0.054  |        1.0         |
# | 159 |          frozenset({' Razors', 'Milk ', ' Paper Towels '})           |             frozenset({' Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 160 |           frozenset({'Milk ', ' Milk ', ' Paper Towels '})           |             frozenset({' Razors', ' Toilet Paper '})             |  0.054  |        1.0         |
# | 161 |       frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})       |                 frozenset({' Razors', ' Milk '})                 |  0.054  |        1.0         |
# | 162 |              frozenset({' Razors', 'Milk ', ' Milk '})               |         frozenset({' Toilet Paper ', ' Paper Towels '})          |  0.054  |        1.0         |
# | 163 |          frozenset({' Razors', 'Milk ', ' Toilet Paper '})           |             frozenset({' Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 164 |           frozenset({'Milk ', ' Toilet Paper ', ' Milk '})           |             frozenset({' Razors', ' Paper Towels '})             |  0.054  |        1.0         |
# | 165 |          frozenset({' Razors', ' Milk ', ' Paper Towels '})          |              frozenset({'Milk ', ' Toilet Paper '})              |  0.054  |        1.0         |
# | 166 |      frozenset({' Razors', ' Toilet Paper ', ' Paper Towels '})      |                  frozenset({'Milk ', ' Milk '})                  |  0.054  |        1.0         |
# | 167 |      frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})       |                 frozenset({' Razors', 'Milk '})                  |  0.054  |        1.0         |
# | 168 |          frozenset({' Razors', ' Milk ', ' Toilet Paper '})          |              frozenset({'Milk ', ' Paper Towels '})              |  0.054  |        1.0         |
# | 169 |                frozenset({'Milk ', ' Paper Towels '})                |        frozenset({' Razors', ' Milk ', ' Toilet Paper '})        |  0.054  |        1.0         |
# | 170 |                   frozenset({' Razors', 'Milk '})                    |    frozenset({' Milk ', ' Toilet Paper ', ' Paper Towels '})     |  0.054  |        1.0         |
# | 171 |                frozenset({'Milk ', ' Toilet Paper '})                |        frozenset({' Razors', ' Milk ', ' Paper Towels '})        |  0.054  |        1.0         |
# | 172 |               frozenset({' Razors', ' Paper Towels '})               |         frozenset({'Milk ', ' Toilet Paper ', ' Milk '})         |  0.054  |        1.0         |
# | 173 |               frozenset({' Milk ', ' Paper Towels '})                |        frozenset({' Razors', 'Milk ', ' Toilet Paper '})         |  0.054  |        1.0         |
# | 174 |           frozenset({' Toilet Paper ', ' Paper Towels '})            |            frozenset({' Razors', 'Milk ', ' Milk '})             |  0.054  |        1.0         |
# | 175 |                   frozenset({' Razors', ' Milk '})                   |     frozenset({'Milk ', ' Toilet Paper ', ' Paper Towels '})     |  0.054  | 0.5094339622641509 |
# | 176 |               frozenset({' Razors', ' Toilet Paper '})               |         frozenset({'Milk ', ' Milk ', ' Paper Towels '})         |  0.054  |        1.0         |
# | 177 |               frozenset({' Milk ', ' Toilet Paper '})                |        frozenset({' Razors', 'Milk ', ' Paper Towels '})         |  0.054  |        1.0         |
# | 178 |                    frozenset({' Paper Towels '})                     |   frozenset({' Razors', 'Milk ', ' Toilet Paper ', ' Milk '})    |  0.054  |        1.0         |
# | 179 |                       frozenset({' Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# | 180 |                        frozenset({'Lotion '})                        |                     frozenset({' Lotion '})                      |  0.051  |        1.0         |
# | 181 |                       frozenset({' Lotion '})                        |                      frozenset({'Lotion '})                      |  0.051  |        1.0         |
# | 182 |                        frozenset({'Lotion '})                        |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# | 183 |                   frozenset({' Milk', 'Lotion '})                    |                     frozenset({' Lotion '})                      |  0.051  |        1.0         |
# | 184 |                   frozenset({' Milk', ' Lotion '})                   |                      frozenset({'Lotion '})                      |  0.051  |        1.0         |
# | 185 |                  frozenset({'Lotion ', ' Lotion '})                  |                       frozenset({' Milk'})                       |  0.051  |        1.0         |
# | 186 |                        frozenset({'Lotion '})                        |                 frozenset({' Milk', ' Lotion '})                 |  0.051  |        1.0         |
# | 187 |                       frozenset({' Lotion '})                        |                 frozenset({' Milk', 'Lotion '})                  |  0.051  |        1.0         |
# | 188 |                       frozenset({' Razors '})                        |                     frozenset({' Dog Food'})                     |  0.053  |        1.0         |
# +-----+----------------------------------------------------------------------+------------------------------------------------------------------+---------+--------------------+
#
# Execution time for walmart_data.csv: 0.04 seconds
#
#
# Frequent Itemsets from best_buy_data.csv:
#
# +----+----------------------------------------------------------------+---------+
# |    |                            Itemsets                            | Support |
# +----+----------------------------------------------------------------+---------+
# | 0  |                    frozenset({'Keyboard '})                    |  0.12   |
# | 1  |                   frozenset({' Keyboard '})                    |  0.055  |
# | 2  |                   frozenset({' Smartwatch'})                   |  0.127  |
# | 3  |                   frozenset({'Smartwatch'})                    |  0.058  |
# | 4  |               frozenset({'External Hard Drive'})               |  0.051  |
# | 5  |              frozenset({' External Hard Drive'})               |  0.051  |
# | 6  |                    frozenset({' Printer '})                    |  0.172  |
# | 7  |                    frozenset({'Speakers '})                    |  0.122  |
# | 8  |              frozenset({' External Hard Drive '})              |  0.114  |
# | 9  |                     frozenset({'Router '})                     |  0.12   |
# | 10 |                    frozenset({' Charger '})                    |  0.106  |
# | 11 |                   frozenset({' Speakers '})                    |  0.133  |
# | 12 |                   frozenset({'Smartwatch '})                   |  0.124  |
# | 13 |                    frozenset({' Router '})                     |  0.201  |
# | 14 |                    frozenset({' Charger'})                     |  0.126  |
# | 15 |                    frozenset({' Printer'})                     |  0.07   |
# | 16 |              frozenset({'External Hard Drive '})               |  0.059  |
# | 17 |                    frozenset({' Keyboard'})                    |  0.161  |
# | 18 |                    frozenset({'Keyboard'})                     |  0.114  |
# | 19 |                  frozenset({' Smartphone '})                   |  0.053  |
# | 20 |                   frozenset({'Smartphone '})                   |  0.053  |
# | 21 |                  frozenset({' Smartwatch '})                   |  0.051  |
# | 22 |                   frozenset({' Smartphone'})                   |  0.063  |
# | 23 |                   frozenset({'Smartphone'})                    |  0.063  |
# | 24 |              frozenset({' Charger', 'Keyboard '})              |  0.067  |
# | 25 |              frozenset({'Keyboard ', ' Router '})              |  0.067  |
# | 26 |        frozenset({' Charger', 'Keyboard ', ' Router '})        |  0.067  |
# | 27 |             frozenset({'Keyboard ', ' Keyboard '})             |  0.055  |
# | 28 |             frozenset({' Router ', ' Smartwatch'})             |  0.069  |
# | 29 |            frozenset({'Smartwatch', ' Smartwatch'})            |  0.058  |
# | 30 |   frozenset({' External Hard Drive', 'External Hard Drive'})   |  0.051  |
# | 31 |             frozenset({'Speakers ', ' Printer '})              |  0.066  |
# | 32 |       frozenset({' Printer ', ' External Hard Drive '})        |  0.113  |
# | 33 |       frozenset({'Speakers ', ' External Hard Drive '})        |  0.066  |
# | 34 | frozenset({'Speakers ', ' Printer ', ' External Hard Drive '}) |  0.066  |
# | 35 |              frozenset({'Router ', ' Speakers '})              |  0.07   |
# | 36 |              frozenset({'Router ', ' Charger '})               |  0.05   |
# | 37 |             frozenset({'Speakers ', ' Charger '})              |  0.056  |
# | 38 |             frozenset({' Printer ', ' Speakers '})             |  0.062  |
# | 39 |            frozenset({'Smartwatch ', ' Speakers '})            |  0.059  |
# | 40 |            frozenset({'Smartwatch ', ' Printer '})             |  0.059  |
# | 41 |             frozenset({' Router ', 'Smartwatch '})             |  0.065  |
# | 42 |     frozenset({' Printer ', 'Smartwatch ', ' Speakers '})      |  0.059  |
# | 43 |              frozenset({' Charger', ' Router '})               |  0.067  |
# | 44 |               frozenset({'Router ', ' Printer'})               |  0.07   |
# | 45 |             frozenset({' Speakers ', ' Printer'})              |  0.07   |
# | 46 |        frozenset({'Router ', ' Speakers ', ' Printer'})        |  0.07   |
# | 47 |        frozenset({' Charger', 'External Hard Drive '})         |  0.059  |
# | 48 |              frozenset({' Keyboard', 'Keyboard'})              |  0.114  |
# | 49 |           frozenset({'Smartphone ', ' Smartphone '})           |  0.053  |
# | 50 |            frozenset({' Smartphone', 'Smartphone'})            |  0.063  |
# +----+----------------------------------------------------------------+---------+
#
# Derived Association Rules:
#
# +----+---------------------------------------------------+---------------------------------------------------+---------+--------------------+
# |    |                    Antecedents                    |                    Consequents                    | Support |     Confidence     |
# +----+---------------------------------------------------+---------------------------------------------------+---------+--------------------+
# | 0  |              frozenset({' Charger'})              |             frozenset({'Keyboard '})              |  0.067  | 0.5317460317460317 |
# ...
# | 31 |              frozenset({'Router '})               |              frozenset({' Printer'})              |  0.07   | 0.5833333333333334 |
# | 32 |              frozenset({' Printer'})              |              frozenset({'Router '})               |  0.07   |        1.0         |
# | 33 |             frozenset({' Speakers '})             |              frozenset({' Printer'})              |  0.07   | 0.5263157894736842 |
# | 34 |              frozenset({' Printer'})              |             frozenset({' Speakers '})             |  0.07   |        1.0         |
# | 35 |       frozenset({'Router ', ' Speakers '})        |              frozenset({' Printer'})              |  0.07   |        1.0         |
# | 36 |        frozenset({'Router ', ' Printer'})         |             frozenset({' Speakers '})             |  0.07   |        1.0         |
# | 37 |       frozenset({' Speakers ', ' Printer'})       |              frozenset({'Router '})               |  0.07   |        1.0         |
# | 38 |              frozenset({'Router '})               |       frozenset({' Speakers ', ' Printer'})       |  0.07   | 0.5833333333333334 |
# | 39 |             frozenset({' Speakers '})             |        frozenset({'Router ', ' Printer'})         |  0.07   | 0.5263157894736842 |
# | 40 |              frozenset({' Printer'})              |       frozenset({'Router ', ' Speakers '})        |  0.07   |        1.0         |
# | 41 |        frozenset({'External Hard Drive '})        |              frozenset({' Charger'})              |  0.059  |        1.0         |
# | 42 |             frozenset({' Keyboard'})              |              frozenset({'Keyboard'})              |  0.114  | 0.7080745341614907 |
# | 43 |              frozenset({'Keyboard'})              |             frozenset({' Keyboard'})              |  0.114  |        1.0         |
# | 44 |            frozenset({'Smartphone '})             |            frozenset({' Smartphone '})            |  0.053  |        1.0         |
# | 45 |            frozenset({' Smartphone '})            |            frozenset({'Smartphone '})             |  0.053  |        1.0         |
# | 46 |            frozenset({' Smartphone'})             |             frozenset({'Smartphone'})             |  0.063  |        1.0         |
# | 47 |             frozenset({'Smartphone'})             |            frozenset({' Smartphone'})             |  0.063  |        1.0         |
# +----+---------------------------------------------------+---------------------------------------------------+---------+--------------------+
#
# Execution time for best_buy_data.csv: 0.01 seconds
#
#
# Frequent Itemsets from costco_data.csv:
#
# +----+-----------------------------------------------------------------------------+---------+
# |    |                                  Itemsets                                   | Support |
# +----+-----------------------------------------------------------------------------+---------+
# | 0  |                        frozenset({' Bulk Fruits '})                         |  0.232  |
# | 1  |                         frozenset({'Bulk Fruits '})                         |  0.113  |
# | 2  |                        frozenset({' Optical Items'})                        |  0.179  |
# | 3  |                          frozenset({' Jewelry '})                           |  0.056  |
# | 4  |                        frozenset({'Bakery Items '})                         |  0.236  |
# | 5  |                       frozenset({' Optical Items '})                        |  0.121  |
# | 6  |                      frozenset({' Cleaning Supplies'})                      |  0.12   |
# | 7  |                         frozenset({' Bulk Fruits'})                         |  0.052  |
# | 8  |                           frozenset({' Tires '})                            |  0.16   |
# | 9  |                      frozenset({' Garden Supplies '})                       |  0.105  |
# | 10 |                       frozenset({'Garden Supplies '})                       |  0.052  |
# | 11 |                      frozenset({' Bulk Vegetables '})                       |  0.111  |
# | 12 |                      frozenset({'Cleaning Supplies '})                      |  0.053  |
# | 13 |                        frozenset({' Bakery Items '})                        |  0.076  |
# | 14 |                       frozenset({' Bulk Vegetables'})                       |  0.073  |
# | 15 |                           frozenset({'Jewelry '})                           |  0.073  |
# | 16 |                       frozenset({' Garden Supplies'})                       |  0.162  |
# | 17 |                           frozenset({' Jewelry'})                           |  0.099  |
# | 18 |                        frozenset({'Optical Items'})                         |  0.051  |
# | 19 |                frozenset({'Bakery Items ', ' Bulk Fruits '})                |  0.059  |
# | 20 |                frozenset({'Bulk Fruits ', ' Bulk Fruits '})                 |  0.064  |
# | 21 |                   frozenset({' Tires ', 'Bulk Fruits '})                    |  0.05   |
# | 22 |               frozenset({' Optical Items', ' Bulk Fruits '})                |  0.054  |
# | 23 |                 frozenset({' Optical Items', ' Jewelry '})                  |  0.054  |
# | 24 |                  frozenset({' Jewelry ', ' Bulk Fruits '})                  |  0.054  |
# | 25 |         frozenset({' Optical Items', ' Jewelry ', ' Bulk Fruits '})         |  0.054  |
# | 26 |               frozenset({' Optical Items ', 'Bakery Items '})               |  0.066  |
# | 27 |               frozenset({' Optical Items ', ' Bulk Fruits '})               |  0.055  |
# | 28 |            frozenset({' Optical Items ', ' Cleaning Supplies'})             |  0.066  |
# | 29 |             frozenset({' Cleaning Supplies', 'Bakery Items '})              |  0.066  |
# | 30 |    frozenset({' Optical Items ', ' Cleaning Supplies', 'Bakery Items '})    |  0.066  |
# | 31 |                frozenset({' Bulk Fruits', 'Bakery Items '})                 |  0.052  |
# | 32 |                 frozenset({' Tires ', ' Garden Supplies'})                  |  0.058  |
# | 33 |                 frozenset({' Garden Supplies ', ' Tires '})                 |  0.052  |
# | 34 |            frozenset({' Garden Supplies ', ' Bulk Vegetables '})            |  0.053  |
# | 35 |            frozenset({'Garden Supplies ', ' Garden Supplies '})             |  0.052  |
# | 36 |                 frozenset({'Garden Supplies ', ' Tires '})                  |  0.052  |
# | 37 |       frozenset({'Garden Supplies ', ' Tires ', ' Garden Supplies '})       |  0.052  |
# | 38 |                 frozenset({' Bulk Vegetables ', ' Tires '})                 |  0.058  |
# | 39 |            frozenset({' Bulk Vegetables ', ' Garden Supplies'})             |  0.058  |
# | 40 |       frozenset({' Bulk Vegetables ', ' Tires ', ' Garden Supplies'})       |  0.058  |
# | 41 |           frozenset({' Garden Supplies ', 'Cleaning Supplies '})            |  0.053  |
# | 42 |           frozenset({' Bulk Vegetables ', 'Cleaning Supplies '})            |  0.053  |
# | 43 | frozenset({' Garden Supplies ', ' Bulk Vegetables ', 'Cleaning Supplies '}) |  0.053  |
# | 44 |               frozenset({' Bakery Items ', ' Optical Items'})               |  0.074  |
# | 45 |                 frozenset({'Jewelry ', ' Bulk Vegetables'})                 |  0.073  |
# | 46 |              frozenset({'Bakery Items ', ' Garden Supplies'})               |  0.059  |
# | 47 |                   frozenset({' Jewelry', 'Bulk Fruits '})                   |  0.05   |
# | 48 |                     frozenset({' Tires ', ' Jewelry'})                      |  0.05   |
# | 49 |             frozenset({' Tires ', ' Jewelry', 'Bulk Fruits '})              |  0.05   |
# | 50 |               frozenset({' Optical Items', 'Optical Items'})                |  0.051  |
# +----+-----------------------------------------------------------------------------+---------+
#
# Derived Association Rules:
#
# +----+--------------------------------------------------------+--------------------------------------------------------+---------+--------------------+
# |    |                      Antecedents                       |                      Consequents                       | Support |     Confidence     |
# +----+--------------------------------------------------------+--------------------------------------------------------+---------+--------------------+
# | 0  |              frozenset({'Bulk Fruits '})               |              frozenset({' Bulk Fruits '})              |  0.064  | 0.5663716814159292 |
# | 1  |                frozenset({' Jewelry '})                |             frozenset({' Optical Items'})              |  0.054  | 0.9642857142857143 |
# | 2  |                frozenset({' Jewelry '})                |              frozenset({' Bulk Fruits '})              |  0.054  | 0.9642857142857143 |
# | 3  |       frozenset({' Optical Items', ' Jewelry '})       |              frozenset({' Bulk Fruits '})              |  0.054  |        1.0         |
# | 4  |     frozenset({' Optical Items', ' Bulk Fruits '})     |                frozenset({' Jewelry '})                |  0.054  |        1.0         |
# | 5  |       frozenset({' Jewelry ', ' Bulk Fruits '})        |             frozenset({' Optical Items'})              |  0.054  |        1.0         |
# | 6  |                frozenset({' Jewelry '})                |     frozenset({' Optical Items', ' Bulk Fruits '})     |  0.054  | 0.9642857142857143 |
# | 7  |             frozenset({' Optical Items '})             |              frozenset({'Bakery Items '})              |  0.066  | 0.5454545454545455 |
# | 8  |             frozenset({' Optical Items '})             |           frozenset({' Cleaning Supplies'})            |  0.066  | 0.5454545454545455 |
# | 9  |           frozenset({' Cleaning Supplies'})            |             frozenset({' Optical Items '})             |  0.066  |        0.55        |
# | 10 |           frozenset({' Cleaning Supplies'})            |              frozenset({'Bakery Items '})              |  0.066  |        0.55        |
# | 11 |  frozenset({' Optical Items ', ' Cleaning Supplies'})  |              frozenset({'Bakery Items '})              |  0.066  |        1.0         |
# | 12 |    frozenset({' Optical Items ', 'Bakery Items '})     |           frozenset({' Cleaning Supplies'})            |  0.066  |        1.0         |
# | 13 |   frozenset({' Cleaning Supplies', 'Bakery Items '})   |             frozenset({' Optical Items '})             |  0.066  |        1.0         |
# | 14 |             frozenset({' Optical Items '})             |   frozenset({' Cleaning Supplies', 'Bakery Items '})   |  0.066  | 0.5454545454545455 |
# | 15 |           frozenset({' Cleaning Supplies'})            |    frozenset({' Optical Items ', 'Bakery Items '})     |  0.066  |        0.55        |
# | 16 |              frozenset({' Bulk Fruits'})               |              frozenset({'Bakery Items '})              |  0.052  |        1.0         |
# | 17 |            frozenset({' Garden Supplies '})            |            frozenset({' Bulk Vegetables '})            |  0.053  | 0.5047619047619047 |
# | 18 |            frozenset({'Garden Supplies '})             |            frozenset({' Garden Supplies '})            |  0.052  |        1.0         |
# | 19 |            frozenset({'Garden Supplies '})             |                 frozenset({' Tires '})                 |  0.052  |        1.0         |
# | 20 |       frozenset({'Garden Supplies ', ' Tires '})       |            frozenset({' Garden Supplies '})            |  0.052  |        1.0         |
# | 21 |  frozenset({'Garden Supplies ', ' Garden Supplies '})  |                 frozenset({' Tires '})                 |  0.052  |        1.0         |
# | 22 |      frozenset({' Garden Supplies ', ' Tires '})       |            frozenset({'Garden Supplies '})             |  0.052  |        1.0         |
# | 23 |            frozenset({'Garden Supplies '})             |      frozenset({' Garden Supplies ', ' Tires '})       |  0.052  |        1.0         |
# | 24 |            frozenset({' Bulk Vegetables '})            |                 frozenset({' Tires '})                 |  0.058  | 0.5225225225225225 |
# | 25 |            frozenset({' Bulk Vegetables '})            |            frozenset({' Garden Supplies'})             |  0.058  | 0.5225225225225225 |
# | 26 |      frozenset({' Bulk Vegetables ', ' Tires '})       |            frozenset({' Garden Supplies'})             |  0.058  |        1.0         |
# | 27 |  frozenset({' Bulk Vegetables ', ' Garden Supplies'})  |                 frozenset({' Tires '})                 |  0.058  |        1.0         |
# | 28 |       frozenset({' Tires ', ' Garden Supplies'})       |            frozenset({' Bulk Vegetables '})            |  0.058  |        1.0         |
# | 29 |            frozenset({' Bulk Vegetables '})            |       frozenset({' Tires ', ' Garden Supplies'})       |  0.058  | 0.5225225225225225 |
# | 30 |            frozenset({' Garden Supplies '})            |           frozenset({'Cleaning Supplies '})            |  0.053  | 0.5047619047619047 |
# | 31 |           frozenset({'Cleaning Supplies '})            |            frozenset({' Garden Supplies '})            |  0.053  |        1.0         |
# | 32 |           frozenset({'Cleaning Supplies '})            |            frozenset({' Bulk Vegetables '})            |  0.053  |        1.0         |
# | 33 | frozenset({' Garden Supplies ', ' Bulk Vegetables '})  |           frozenset({'Cleaning Supplies '})            |  0.053  |        1.0         |
# | 34 | frozenset({' Garden Supplies ', 'Cleaning Supplies '}) |            frozenset({' Bulk Vegetables '})            |  0.053  |        1.0         |
# | 35 | frozenset({' Bulk Vegetables ', 'Cleaning Supplies '}) |            frozenset({' Garden Supplies '})            |  0.053  |        1.0         |
# | 36 |            frozenset({' Garden Supplies '})            | frozenset({' Bulk Vegetables ', 'Cleaning Supplies '}) |  0.053  | 0.5047619047619047 |
# | 37 |           frozenset({'Cleaning Supplies '})            | frozenset({' Garden Supplies ', ' Bulk Vegetables '})  |  0.053  |        1.0         |
# | 38 |             frozenset({' Bakery Items '})              |             frozenset({' Optical Items'})              |  0.074  | 0.9736842105263158 |
# | 39 |                frozenset({'Jewelry '})                 |            frozenset({' Bulk Vegetables'})             |  0.073  |        1.0         |
# | 40 |            frozenset({' Bulk Vegetables'})             |                frozenset({'Jewelry '})                 |  0.073  |        1.0         |
# | 41 |                frozenset({' Jewelry'})                 |              frozenset({'Bulk Fruits '})               |  0.05   | 0.5050505050505051 |
# | 42 |                frozenset({' Jewelry'})                 |                 frozenset({' Tires '})                 |  0.05   | 0.5050505050505051 |
# | 43 |           frozenset({' Tires ', ' Jewelry'})           |              frozenset({'Bulk Fruits '})               |  0.05   |        1.0         |
# | 44 |         frozenset({' Tires ', 'Bulk Fruits '})         |                frozenset({' Jewelry'})                 |  0.05   |        1.0         |
# | 45 |        frozenset({' Jewelry', 'Bulk Fruits '})         |                 frozenset({' Tires '})                 |  0.05   |        1.0         |
# | 46 |                frozenset({' Jewelry'})                 |         frozenset({' Tires ', 'Bulk Fruits '})         |  0.05   | 0.5050505050505051 |
# | 47 |              frozenset({'Optical Items'})              |             frozenset({' Optical Items'})              |  0.051  |        1.0         |
# +----+--------------------------------------------------------+--------------------------------------------------------+---------+--------------------+
#
# Execution time for costco_data.csv: 0.01 seconds
